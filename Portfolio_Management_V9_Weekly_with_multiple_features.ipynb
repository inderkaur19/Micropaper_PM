# %%
################ select features using random forest and then apply lstm #################

# %%
# 1. Import libraries:
# %matplotlib inline
import os
import quandl
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.optimize as spo
from scipy.stats import kurtosis, skew
import seaborn as sns
# from financial_data import *
import tensorflow as tf
mlp.style.use('seaborn')
quandl.save_key('HtwBLPt3k37yZHTvy15K')
# Out:
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/4242266090.py:16: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mlp.style.use('seaborn')

# %%
sp_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500 = pd.read_html(sp_url, header=0)[0]
sp500.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
# Correct invalid dates:
sp500.loc[sp500[sp500['Date added']=='1983-11-30 (1957-03-04)'].index,'Date added'] = '1983-11-30'
sp500.loc[sp500[sp500['Date added']=='2001?'].index,'Date added'] = '2001-01-01'
# Filter firms that entered the index after December 2015:
sp500['Date added'] = pd.to_datetime(sp500['Date added'],format='%Y-%m-%d')
sp500 = sp500[sp500['Date added']<'2007-01-01']
print("The number of stocks in the universe is:", sp500.shape[0])
# Out:
# The number of stocks in the universe is: 241

# %%
n_stocks = 5
np.random.seed(2)
universe_tickers = sp500['Symbol'].unique()
tickers = list(np.random.choice(universe_tickers,replace=False,size=n_stocks))
print(tickers)
# Out:
# ['BK', 'CTAS', 'T', 'CSCO', 'MRK']

# %%
def download_data(tickers, start_date, end_date, columns):
    data = yf.download(tickers, start=start_date, end=end_date)
    data=data[columns]
    return data

# Define the tickers, start date, end date, and columns you want to download
start_date = '2007-01-01'
end_date = '2022-12-31'
columns = [ 'Adj Close', 'Volume','Open','High','Low']

# Download the data
data = download_data(tickers, start_date, end_date, columns)
# print(data)


def one_lvl_colnames(df,cols,tickers):
    """This function changes a multi-level column indexation into a one level
    column indexation

    Inputs:
    -------
    df (pandas Dataframe): dataframe with the columns whose indexation will be 
        flattened.
    tickers (list|string): list/string with the tickers (s) in the data frame df.
    cols (list|string): list/string with the name of the columns (e.g. 'Adj Close',
        'High', 'Close', etc.) that are in the dataframe df.
    
    Ouputs:
    -------
    df (pandas Dataframe): dataframe with the same information as df, but 
        with one level of indexation.
    """
    
    
    df_not_renamed=df.copy()
    # Define important variables:
    if isinstance(tickers, str):
        tickers = [tickers]
    if isinstance(cols, str):
        
        cols = [cols]
#         print(cols)

    # For multi-level column indexing:
    if isinstance(df.columns.values[0], tuple):

        # Define important varibles
        columns = df.columns.values
        new_cols = []

        # Itarate through the multi-level column names and flatten them:
        for col in columns:
            temp = []
            for name in col:
                if name != '':
                    temp.append(name)
            new_temp = '_'.join(temp)
            new_cols.append(new_temp)
        
        # Change the column names:
        df.columns = new_cols
    
    # For uni-level colum indexing:
    elif isinstance(df.columns.values[0], str):
        
        # Define new names:
        col_names = [column+'_'+ticker for column in cols\
                     for ticker in tickers]
        df.columns = col_names
    

    return df

df2=pd.DataFrame(one_lvl_colnames(data,cols=columns,tickers=tickers))
df2_columns=list(df2.columns)
df2.columns = [col.replace('Adj Close', 'Close') for col in df2_columns]
df2.reset_index(inplace=True)

df2['weekday'] = df2['Date'].dt.dayofweek
df2=df2[df2['weekday']==0].reset_index(drop=True)
df2.drop(columns=['weekday'],inplace=True)
df2=df2.set_index('Date')
df2.tail()
# Out:
# [*********************100%%**********************]  5 of 5 completed
#              Close_BK  Close_CSCO  Close_CTAS   Close_MRK    Close_T  \
# Date
# 2022-11-21  43.078903   46.203724  446.185455  102.798195  17.654076
# 2022-11-28  43.223621   46.650047  450.829285  105.562584  17.635336
# 2022-12-05  42.490364   47.862869  455.860138  107.081055  17.569740
# 2022-12-12  43.271858   47.833755  453.885498  106.068733  18.085117
# 2022-12-19  42.615788   45.990269  440.082977  107.232018  16.735764
#
#             Volume_BK  Volume_CSCO  Volume_CTAS  Volume_MRK  Volume_T  ...  \
# Date                                                                   ...
# 2022-11-21    2985400     17049500       240100     8899300  31911400  ...
# 2022-11-28    3626700     14976600       255500     9524500  27780200  ...
# 2022-12-05    3535000     13795900       255200     6961900  28698000  ...
# 2022-12-12    4732800     15425300       352500    10956600  31333500  ...
# 2022-12-19    3739100     17986300       335900     6949500  62216900  ...
#
#               High_BK  High_CSCO   High_CTAS    High_MRK     High_T  \
# Date
# 2022-11-21  44.720001  48.290001  454.459991  105.870003  19.080000
# 2022-11-28  45.450001  48.470001  458.390015  108.900002  19.150000
# 2022-12-05  45.099998  49.639999  459.769989  110.230003  18.980000
# 2022-12-12  45.000000  49.320000  458.600006  109.099998  19.309999
# 2022-12-19  44.580002  47.959999  448.250000  110.099998  18.320000
#
#                Low_BK   Low_CSCO    Low_CTAS     Low_MRK      Low_T
# Date
# 2022-11-21  44.209999  47.560001  448.440002  104.230003  18.760000
# 2022-11-28  44.689999  47.919998  452.019989  107.129997  18.770000
# 2022-12-05  43.770000  49.169998  454.730011  109.209999  18.690001
# 2022-12-12  44.509998  48.369999  452.390015  107.320000  19.070000
# 2022-12-19  43.910000  47.139999  441.209991  108.769997  17.639999
#
# [5 rows x 25 columns]

# %%
pd.set_option('display.max_rows', 100)

# %%
from stockstats import StockDataFrame
def extract_and_wrap_ticker_data(df, columns):
    # Split column names into parts
    parts = [col.split('_') for col in columns]

    # Create a dictionary to store information about each ticker
    ticker_info = {}

    # Iterate through the parts list
    for part in parts:
        data_type = part[0]  # e.g., 'Adj Close', 'Close', etc.
        ticker = part[1]     # e.g., 'AAPL', 'GOOGL', etc.

        # Check if the ticker is already in the dictionary
        if ticker not in ticker_info:
            ticker_info[ticker] = {}

        # Add information for the ticker
        ticker_info[ticker][data_type] = df[f'{data_type}_{ticker}']

    # Create a dictionary to store stockstats DataFrames for each ticker
    ticker_dataframes = pd.DataFrame()

    # Iterate through ticker_info and wrap data with stockstats
    for ticker, data in ticker_info.items():
        df = pd.DataFrame(data)
        print(ticker)
        
        stock_df = StockDataFrame.retype(df)

        stock_df.init_all()
        stock_df.drop(columns=['tp','rate','change'],inplace=True)
        stock_df.columns = [ticker+"_" + col for col in pd.DataFrame(stock_df).columns]
        ticker_dataframes = pd.concat([ticker_dataframes,stock_df],axis=1)
        
    return ticker_dataframes

# Sample DataFrame with specified columns
columns = list(df2.columns)
# print(columns)



# Extract and wrap ticker data
ticker_dataframes = extract_and_wrap_ticker_data(df2, columns)

ticker_dataframes
# Out:
# BK
# CSCO
# CTAS
# MRK
# T
#              BK_close  BK_volume    BK_open    BK_high     BK_low  BK_middle  \
# Date
# 2007-01-08  28.533619    3788223  41.795631  42.081833  41.445835  37.353762
# 2007-01-22  29.557217    3930487  43.428024  43.459827  43.078228  38.698424
# 2007-01-29  28.933897    5153794  42.590630  42.972229  42.081833  37.995986
# 2007-02-05  29.926861    5174172  43.173626  43.968624  43.141827  39.012437
# 2007-02-12  30.506702    3961337  44.095825  44.636421  44.074623  39.739249
# ...               ...        ...        ...        ...        ...        ...
# 2022-11-21  43.078903    2985400  44.419998  44.720001  44.209999  44.002968
# 2022-11-28  43.223621    3626700  45.250000  45.450001  44.689999  44.454540
# 2022-12-05  42.490364    3535000  44.980000  45.099998  43.770000  43.786788
# 2022-12-12  43.271858    4732800  44.709999  45.000000  44.509998  44.260619
# 2022-12-19  42.615788    3739100  44.040001  44.580002  43.910000  43.701930
#
#               BK_boll  BK_boll_ub  BK_boll_lb   BK_macd  ...     T_pgo  \
# Date                                                     ...
# 2007-01-08  28.533619         NaN         NaN  0.000000  ...  0.000000
# 2007-01-22  29.045418   30.493004   27.597832  0.022965  ...  0.008565
# 2007-01-29  29.008244   30.039910   27.976578  0.009933  ...  0.015020
# 2007-02-05  29.237898   30.484258   27.991538  0.039613  ...  0.021765
# 2007-02-12  29.491659   31.057849   27.925469  0.077980  ...  0.009987
# ...               ...         ...         ...       ...  ...       ...
# 2022-11-21  40.539208   43.898001   37.180415 -1.029556  ...  0.970152
# 2022-11-28  40.659142   44.225765   37.092518 -0.760422  ...  0.938164
# 2022-12-05  40.806409   44.422227   37.190591 -0.599391  ...  0.878076
# 2022-12-12  40.942502   44.719006   37.165997 -0.404054  ...  1.111861
# 2022-12-19  41.016437   44.866170   37.166703 -0.298744  ...  0.254521
#
#                 T_psl       T_rsi        T_rsv  T_stochrsi     T_tema  \
# Date
# 2007-01-08   0.000000         NaN -2914.912560         NaN   7.470336
# 2007-01-22   8.333333  100.000000  -986.732454         NaN   7.772279
# 2007-01-29  16.666667  100.000000  -604.005829         NaN   8.045893
# 2007-02-05  25.000000  100.000000  -453.066933         NaN   8.328255
# 2007-02-12  25.000000   80.501382  -458.032304    0.000000   8.258640
# ...               ...         ...          ...         ...        ...
# 2022-11-21  50.000000   56.790593    62.914677   94.507501  18.012246
# 2022-11-28  50.000000   56.643506    62.507292   93.985427  17.937336
# 2022-12-05  50.000000   56.095829    61.081301   92.041485  17.798013
# 2022-12-12  58.333333   59.416028    70.213012  100.000000  18.059098
# 2022-12-19  58.333333   48.973514   -33.209921   64.300987  17.193495
#
#               T_trix         T_wr        T_vr     T_vwma
# Date
# 2007-01-08  0.000000 -3014.912560  100.000000  19.413576
# 2007-01-22  0.686286 -1086.732454  206.406975  19.740313
# 2007-01-29  0.720751  -704.005829  305.041082  20.077635
# 2007-02-05  0.773311  -553.066933  434.113037  20.506962
# 2007-02-12  0.712437  -558.032304  261.046001  20.595881
# ...              ...          ...         ...        ...
# 2022-11-21 -0.353214   -37.085323  119.018594  16.770726
# 2022-11-28 -0.254621   -37.492708  129.598761  16.800084
# 2022-12-05 -0.159793   -38.918699  110.956361  16.830324
# 2022-12-12 -0.061490   -27.714851  109.130361  16.915016
# 2022-12-19  0.003350   -57.048627   87.828100  16.989468
#
# [756 rows x 355 columns]

# %%
len(['close', 'volume', 'open', 'high', 'low', 'middle', 'tp','rate',
       'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos',
       'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1',
       'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2',
       'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull',
       'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci',
       'change', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr',
       'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo',
       'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma'])
# Out:
# 74

# %%
# Define the tickers
new_tickers = ['EIA/PET_RWTC_D','FRED/T10Y2Y','FRED/T10Y3M','FRED/DTB3','FRED/DLTIIT','FRED/TEDRATE']

# # Define the date range
names = ['wti_spot','10y2y_spread','10y3m_spread','3m_rate','ltiit','ted_spread']

# # Retrieve data
data_quandl = quandl.get(new_tickers, start_date=start_date, end_date=end_date)
data_quandl.columns = names
data_quandl['var_wti'] = data_quandl['wti_spot'].pct_change()
# # Print the data
print(data_quandl)
# Out:
#            wti_spot  10y2y_spread  10y3m_spread  3m_rate  ltiit  ted_spread  \
# Date
# 2007-01-02      NaN         -0.12         -0.39     4.94   2.33        0.42
# 2007-01-03      NaN         -0.09         -0.38     4.92   2.32        0.44
# 2007-01-04      NaN         -0.09         -0.42     4.91   2.30        0.45
# 2007-01-05      NaN         -0.11         -0.40     4.92   2.33        0.44
# 2007-01-08      NaN         -0.12         -0.42     4.95   2.34        0.41
# ...             ...           ...           ...      ...    ...         ...
# 2022-07-12      NaN         -0.07          0.74     2.16   1.12         NaN
# 2022-07-13      NaN         -0.22          0.52     2.33   1.06         NaN
# 2022-07-14      NaN         -0.19          0.56     2.33   1.07         NaN
# 2022-07-15      NaN         -0.20          0.56     2.29   1.03         NaN
# 2022-07-18      NaN         -0.19          0.46      NaN    NaN         NaN
#
#             var_wti
# Date
# 2007-01-02      NaN
# 2007-01-03      NaN
# 2007-01-04      NaN
# 2007-01-05      NaN
# 2007-01-08      NaN
# ...             ...
# 2022-07-12      NaN
# 2022-07-13      NaN
# 2022-07-14      NaN
# 2022-07-15      NaN
# 2022-07-18      NaN
#
# [3891 rows x 7 columns]

# %%
temp=ticker_dataframes.reset_index()
max_date=data_quandl.reset_index()['Date'].max()
temp=temp[temp['Date']<=max_date]
temp
# Out:
#           Date   BK_close  BK_volume    BK_open    BK_high     BK_low  \
# 0   2007-01-08  28.533619    3788223  41.795631  42.081833  41.445835
# 1   2007-01-22  29.557217    3930487  43.428024  43.459827  43.078228
# 2   2007-01-29  28.933897    5153794  42.590630  42.972229  42.081833
# 3   2007-02-05  29.926861    5174172  43.173626  43.968624  43.141827
# 4   2007-02-12  30.506702    3961337  44.095825  44.636421  44.074623
# ..         ...        ...        ...        ...        ...        ...
# 730 2022-06-06  43.564941    3018200  46.060001  46.740002  45.830002
# 731 2022-06-13  39.317482    6128700  41.950001  42.139999  41.130001
# 732 2022-06-27  40.824951    3135500  43.709999  43.779999  42.869999
# 733 2022-07-11  39.545017    2285100  41.450001  41.939999  41.200001
# 734 2022-07-18  40.550003    4314700  43.930000  44.410000  42.520000
#
#      BK_middle    BK_boll  BK_boll_ub  BK_boll_lb  ...     T_pgo      T_psl  \
# 0    37.353762  28.533619         NaN         NaN  ...  0.000000   0.000000
# 1    38.698424  29.045418   30.493004   27.597832  ...  0.008565   8.333333
# 2    37.995986  29.008244   30.039910   27.976578  ...  0.015020  16.666667
# 3    39.012437  29.237898   30.484258   27.991538  ...  0.021765  25.000000
# 4    39.739249  29.491659   31.057849   27.925469  ...  0.009987  25.000000
# ..         ...        ...         ...         ...  ...       ...        ...
# 730  45.378315  48.452585   61.088001   35.817168  ...  0.809940  83.333333
# 731  40.862494  47.682637   60.584805   34.780469  ...  0.303502  83.333333
# 732  42.491650  46.787470   58.924479   34.650461  ...  0.596790  83.333333
# 733  40.895006  46.010663   57.898805   34.122522  ...  0.559811  83.333333
# 734  42.493334  45.251038   56.441984   34.060092  ...  0.420845  75.000000
#
#           T_rsi        T_rsv  T_stochrsi     T_tema    T_trix         T_wr  \
# 0           NaN -2914.912560         NaN   7.470336  0.000000 -3014.912560
# 1    100.000000  -986.732454         NaN   7.772279  0.686286 -1086.732454
# 2    100.000000  -604.005829         NaN   8.045893  0.720751  -704.005829
# 3    100.000000  -453.066933         NaN   8.328255  0.773311  -553.066933
# 4     80.501382  -458.032304    0.000000   8.258640  0.712437  -558.032304
# ..          ...          ...         ...        ...       ...          ...
# 730   67.329138    37.683922  100.000000  19.079880  0.287529   -52.956741
# 731   55.558635   -40.731885   59.457084  18.405624  0.351280   -81.009414
# 732   61.778752     0.943659   80.881969  18.731184  0.412212   -56.760558
# 733   62.635567     7.381792   82.566205  18.961439  0.468712   -56.180064
# 734   61.377689     1.916408   72.524432  18.959098  0.514244   -66.136255
#
#            T_vr     T_vwma
# 0    100.000000  19.413576
# 1    206.406975  19.740313
# 2    305.041082  20.077635
# 3    434.113037  20.506962
# 4    261.046001  20.595881
# ..          ...        ...
# 730  113.564956  18.297390
# 731  115.611443  18.451615
# 732  130.163970  18.595534
# 733  148.160197  18.799397
# 734  163.447108  18.963034
#
# [735 rows x 356 columns]

# %%
final_df=pd.merge(temp,data_quandl.reset_index(),on=['Date'],how='left')

final_df
# Out:
#           Date   BK_close  BK_volume    BK_open    BK_high     BK_low  \
# 0   2007-01-08  28.533619    3788223  41.795631  42.081833  41.445835
# 1   2007-01-22  29.557217    3930487  43.428024  43.459827  43.078228
# 2   2007-01-29  28.933897    5153794  42.590630  42.972229  42.081833
# 3   2007-02-05  29.926861    5174172  43.173626  43.968624  43.141827
# 4   2007-02-12  30.506702    3961337  44.095825  44.636421  44.074623
# ..         ...        ...        ...        ...        ...        ...
# 730 2022-06-06  43.564941    3018200  46.060001  46.740002  45.830002
# 731 2022-06-13  39.317482    6128700  41.950001  42.139999  41.130001
# 732 2022-06-27  40.824951    3135500  43.709999  43.779999  42.869999
# 733 2022-07-11  39.545017    2285100  41.450001  41.939999  41.200001
# 734 2022-07-18  40.550003    4314700  43.930000  44.410000  42.520000
#
#      BK_middle    BK_boll  BK_boll_ub  BK_boll_lb  ...         T_wr  \
# 0    37.353762  28.533619         NaN         NaN  ... -3014.912560
# 1    38.698424  29.045418   30.493004   27.597832  ... -1086.732454
# 2    37.995986  29.008244   30.039910   27.976578  ...  -704.005829
# 3    39.012437  29.237898   30.484258   27.991538  ...  -553.066933
# 4    39.739249  29.491659   31.057849   27.925469  ...  -558.032304
# ..         ...        ...         ...         ...  ...          ...
# 730  45.378315  48.452585   61.088001   35.817168  ...   -52.956741
# 731  40.862494  47.682637   60.584805   34.780469  ...   -81.009414
# 732  42.491650  46.787470   58.924479   34.650461  ...   -56.760558
# 733  40.895006  46.010663   57.898805   34.122522  ...   -56.180064
# 734  42.493334  45.251038   56.441984   34.060092  ...   -66.136255
#
#            T_vr     T_vwma  wti_spot  10y2y_spread  10y3m_spread  3m_rate  \
# 0    100.000000  19.413576       NaN         -0.12         -0.42     4.95
# 1    206.406975  19.740313       NaN         -0.15         -0.37     5.00
# 2    305.041082  20.077635       NaN         -0.09         -0.24     5.01
# 3    434.113037  20.506962       NaN         -0.11         -0.34     5.02
# 4    261.046001  20.595881       NaN         -0.14         -0.38     5.04
# ..          ...        ...       ...           ...           ...      ...
# 730  113.564956  18.297390       NaN          0.31          1.78     1.23
# 731  115.611443  18.451615       NaN          0.03          1.70     1.69
# 732  130.163970  18.595534       NaN          0.12          1.41     1.75
# 733  148.160197  18.799397       NaN         -0.08          0.81     2.13
# 734  163.447108  18.963034       NaN         -0.19          0.46      NaN
#
#      ltiit  ted_spread  var_wti
# 0     2.34        0.41      NaN
# 1     2.39        0.36      NaN
# 2     2.46        0.35      NaN
# 3     2.39        0.34      NaN
# 4     2.44        0.32      NaN
# ..     ...         ...      ...
# 730   0.75         NaN      NaN
# 731   1.04         NaN      NaN
# 732   1.03         NaN      NaN
# 733   1.16         NaN      NaN
# 734    NaN         NaN      NaN
#
# [735 rows x 363 columns]

# %%
pd.DataFrame(final_df.isnull().sum()).sort_values(by=0,ascending=False)
# Out:
#                 0
# var_wti       735
# wti_spot      735
# T_cr-ma1      643
# T_cr-ma2      640
# T_cr-ma3      634
# ...           ...
# CSCO_ndi        0
# CSCO_mfi        0
# CSCO_ker        0
# CSCO_kdjj       0
# CTAS_eribear    0
#
# [363 rows x 1 columns]

# %%
final_df2=final_df.copy()

# %%
# final_df2=final_df.copy()

for ticker in tickers:
    final_df2[ticker+"_close"] = final_df2[ticker+"_close"].pct_change()
final_df2.fillna(method='ffill',inplace=True)
final_df2.fillna(method='bfill',inplace=True)
final_df2.set_index(['Date'],inplace=True)

final_df2
# Out:
#             BK_close  BK_volume    BK_open    BK_high     BK_low  BK_middle  \
# Date
# 2007-01-08  0.035873    3788223  41.795631  42.081833  41.445835  37.353762
# 2007-01-22  0.035873    3930487  43.428024  43.459827  43.078228  38.698424
# 2007-01-29 -0.021089    5153794  42.590630  42.972229  42.081833  37.995986
# 2007-02-05  0.034318    5174172  43.173626  43.968624  43.141827  39.012437
# 2007-02-12  0.019375    3961337  44.095825  44.636421  44.074623  39.739249
# ...              ...        ...        ...        ...        ...        ...
# 2022-06-06  0.028424    3018200  46.060001  46.740002  45.830002  45.378315
# 2022-06-13 -0.097497    6128700  41.950001  42.139999  41.130001  40.862494
# 2022-06-27  0.038341    3135500  43.709999  43.779999  42.869999  42.491650
# 2022-07-11 -0.031352    2285100  41.450001  41.939999  41.200001  40.895006
# 2022-07-18  0.025414    4314700  43.930000  44.410000  42.520000  42.493334
#
#               BK_boll  BK_boll_ub  BK_boll_lb   BK_macd  ...         T_wr  \
# Date                                                     ...
# 2007-01-08  28.533619   30.493004   27.597832  0.000000  ... -3014.912560
# 2007-01-22  29.045418   30.493004   27.597832  0.022965  ... -1086.732454
# 2007-01-29  29.008244   30.039910   27.976578  0.009933  ...  -704.005829
# 2007-02-05  29.237898   30.484258   27.991538  0.039613  ...  -553.066933
# 2007-02-12  29.491659   31.057849   27.925469  0.077980  ...  -558.032304
# ...               ...         ...         ...       ...  ...          ...
# 2022-06-06  48.452585   61.088001   35.817168 -2.641393  ...   -52.956741
# 2022-06-13  47.682637   60.584805   34.780469 -2.859839  ...   -81.009414
# 2022-06-27  46.787470   58.924479   34.650461 -2.878141  ...   -56.760558
# 2022-07-11  46.010663   57.898805   34.122522 -2.961784  ...   -56.180064
# 2022-07-18  45.251038   56.441984   34.060092 -2.913394  ...   -66.136255
#
#                   T_vr     T_vwma  wti_spot  10y2y_spread  10y3m_spread  \
# Date
# 2007-01-08  100.000000  19.413576       NaN         -0.12         -0.42
# 2007-01-22  206.406975  19.740313       NaN         -0.15         -0.37
# 2007-01-29  305.041082  20.077635       NaN         -0.09         -0.24
# 2007-02-05  434.113037  20.506962       NaN         -0.11         -0.34
# 2007-02-12  261.046001  20.595881       NaN         -0.14         -0.38
# ...                ...        ...       ...           ...           ...
# 2022-06-06  113.564956  18.297390       NaN          0.31          1.78
# 2022-06-13  115.611443  18.451615       NaN          0.03          1.70
# 2022-06-27  130.163970  18.595534       NaN          0.12          1.41
# 2022-07-11  148.160197  18.799397       NaN         -0.08          0.81
# 2022-07-18  163.447108  18.963034       NaN         -0.19          0.46
#
#             3m_rate  ltiit  ted_spread  var_wti
# Date
# 2007-01-08     4.95   2.34        0.41      NaN
# 2007-01-22     5.00   2.39        0.36      NaN
# 2007-01-29     5.01   2.46        0.35      NaN
# 2007-02-05     5.02   2.39        0.34      NaN
# 2007-02-12     5.04   2.44        0.32      NaN
# ...             ...    ...         ...      ...
# 2022-06-06     1.23   0.75        0.11      NaN
# 2022-06-13     1.69   1.04        0.11      NaN
# 2022-06-27     1.75   1.03        0.11      NaN
# 2022-07-11     2.13   1.16        0.11      NaN
# 2022-07-18     2.13   1.16        0.11      NaN
#
# [735 rows x 362 columns]

# %%
pd.DataFrame(np.isinf(final_df2).sum()).sort_values(by=0,ascending=False).head(50)
# Out:
#                      0
# T_cr               644
# MRK_cr             426
# BK_cr              292
# CSCO_cr            231
# CTAS_cr            102
# MRK_adx              0
# MRK_supertrend       0
# MRK_supertrend_lb    0
# MRK_supertrend_ub    0
# MRK_wt2              0
# MRK_wt1              0
# MRK_log-ret          0
# MRK_adxr             0
# MRK_dx               0
# MRK_cti              0
# MRK_tr               0
# MRK_cr-ma3           0
# MRK_cr-ma2           0
# MRK_cr-ma1           0
# MRK_qqes             0
# MRK_qqel             0
# MRK_qqe              0
# MRK_ppoh             0
# MRK_bop              0
# BK_close             0
# MRK_eribull          0
# MRK_ppos             0
# MRK_ker              0
# MRK_kdjj             0
# MRK_kdjd             0
# MRK_kdjk             0
# MRK_kama             0
# MRK_ftr              0
# MRK_inertia          0
# MRK_ichimoku         0
# MRK_dma              0
# MRK_coppock          0
# MRK_cmo              0
# MRK_chop             0
# MRK_cci              0
# MRK_atr              0
# MRK_aroon            0
# MRK_ao               0
# MRK_kst              0
# MRK_rvgis            0
# MRK_rvgi             0
# MRK_eribear          0
# MRK_pvoh             0
# MRK_ppo              0
# MRK_pvos             0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
def check_var_importance(df,ticker):
    # Separate features (X) and target (y)
    # AAPL_df.drop(columns=["AAPL_cr"],inplace=True)
    
    null_count=pd.DataFrame(df.isnull().sum()).sort_values(by=0,ascending=False).reset_index()
    null_count.columns=['features','nulls']
    null_count.head()
    threshold = len(df)/100

    # Get the column names with too many negative values
    columns_to_drop = null_count[null_count['nulls'] > threshold]['features'].tolist()
    print(columns_to_drop)
    # Drop the columns
    df.drop(columns=columns_to_drop, inplace=True)
    df.replace([np.inf, -np.inf], 0, inplace=True)

    df.ffill(inplace=True)
    df.bfill(inplace=True)
    print("**************************")
#     print(df.isnull())

    X = df  # Use relevant columns
    y = df[ticker+'_close']  # Target variable is 'Close'

    # Standardize features (optional but often recommended for neural networks)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    # Create sequences of length 5 for X and corresponding y for training
    X_train, y_train = [], []

    for i in range(5, len(X)):
        X_train.append(X[i-5:i])
        y_train.append(y[i])

    X_train, y_train = np.array(X_train), np.array(y_train)
    # Step 2: Check Variable Importance
    # Use RandomForestRegressor to determine importance
    rf = RandomForestRegressor(n_estimators=10)
    rf.fit(X_train.reshape(-1, 5 * X.shape[1]), y_train)

    # Get feature importances along with their corresponding feature names
    feature_importances = rf.feature_importances_
    print([feature_importances][0].tolist())
    feature_names = [col.split(ticker+"_")[-1] for col in df.columns]
    print(feature_names)

    # Combine feature names with their importances
    feature_importance_info = list(zip(feature_names, feature_importances))


    # Sort the list by importance (in descending order)
    feature_importance_info.sort(key=lambda x: x[0])

    return pd.DataFrame(feature_importance_info,columns=['Features',ticker+'_Relative_Importance'])

# %%
final_df2.head(2)
features=['close', 'volume', 'open', 'high', 'low', 'middle',
       'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos',
       'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1',
       'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2',
       'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull',
       'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci',
        'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr',
       'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo',
       'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
feat_importance_all=pd.DataFrame()
feat_importance_all['Features']=features
# print(feat_importance_all)
for ticker in tickers:
    
    matching_columns = [f'{ticker}_{i}' for i in features]
    print(matching_columns)

    temp_df=final_df2[matching_columns]
    feat_importance_temp=check_var_importance(temp_df,ticker)
    feat_importance_all=feat_importance_all.merge(feat_importance_temp, on=['Features'], how='left')

feat_importance_all=feat_importance_all.T.drop_duplicates(keep='first').T
feat_importance_all["Average_relative_Importance"]=feat_importance_all.iloc[:,1:].mean(axis=1)
feat_importance_all=feat_importance_all.sort_values(by=['Average_relative_Importance'], ascending=False).reset_index(drop=True)
print(feat_importance_all)
# Out:
# ['BK_close', 'BK_volume', 'BK_open', 'BK_high', 'BK_low', 'BK_middle', 'BK_boll', 'BK_boll_ub', 'BK_boll_lb', 'BK_macd', 'BK_macds', 'BK_macdh', 'BK_pvo', 'BK_pvos', 'BK_pvoh', 'BK_ppo', 'BK_ppos', 'BK_ppoh', 'BK_qqe', 'BK_qqel', 'BK_qqes', 'BK_cr', 'BK_cr-ma1', 'BK_cr-ma2', 'BK_cr-ma3', 'BK_tr', 'BK_dx', 'BK_adx', 'BK_adxr', 'BK_log-ret', 'BK_wt1', 'BK_wt2', 'BK_supertrend_ub', 'BK_supertrend_lb', 'BK_supertrend', 'BK_bop', 'BK_cti', 'BK_eribull', 'BK_eribear', 'BK_rvgi', 'BK_rvgis', 'BK_kst', 'BK_ao', 'BK_aroon', 'BK_atr', 'BK_cci', 'BK_chop', 'BK_cmo', 'BK_coppock', 'BK_dma', 'BK_ichimoku', 'BK_inertia', 'BK_ftr', 'BK_kama', 'BK_kdjk', 'BK_kdjd', 'BK_kdjj', 'BK_ker', 'BK_mfi', 'BK_ndi', 'BK_pdi', 'BK_pgo', 'BK_psl', 'BK_rsi', 'BK_rsv', 'BK_stochrsi', 'BK_tema', 'BK_trix', 'BK_wr', 'BK_vr', 'BK_vwma']
# []
# **************************
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 0, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ffill(inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bfill(inplace=True)
# [0.0010449526627606795, 0.005680093633375711, 0.000931465936910176, 0.0004603059012442857, 0.0012345686091163111, 0.00015840382214091169, 8.478158307276332e-05, 0.00017354476998333206, 0.0001081675200244251, 1.3510607822670345e-05, 0.007827024137437548, 9.630183044075468e-05, 0.0016495062351506813, 0.0017832722187864863, 0.0005726213578510271, 0.008471238452979039, 0.004087127703717475, 0.0011240221488132579, 0.0010997106413639186, 0.00020699004279501698, 0.0001360986786981157, 0.0027379152132688328, 0.00012805359877252637, 0.005608188638704017, 0.0009736950050852981, 0.005552804031422909, 0.009699518992015812, 0.00435441366803997, 0.0037179995219128715, 0.001694776884712726, 0.006065000132431087, 0.010780919530946466, 5.803499360260839e-06, 7.695695106411474e-05, 0.0003099050357263384, 0.00553037648317836, 0.014316761193965846, 0.0012326418549379137, 0.005413891464419808, 0.0001741993459820417, 0.0001234005929760032, 6.753588090032733e-05, 0.007494904421945485, 0.0009143458418094702, 0.00040276187840439443, 0.009045332075614768, 8.63116983136359e-05, 0.0006731762959801548, 0.002052269261319223, 0.00327376647847665, 0.000565732775298537, 0.0031950616030775618, 0.0045701369533116855, 0.0012036707345127375, 0.0004294632269290696, 0.0016746873439167666, 0.0009364269157209786, 0.01663730836079701, 0.004449931712887044, 0.004889829359263925, 0.001149453263266983, 0.001671250111967401, 0.00013414040441887633, 0.002289913618764773, 0.0008300084910914306, 0.002563039848388739, 8.946218059999611e-06, 0.002560410947020337, 0.007261626678899021, 0.0019215484385939842, 0.00045763603169556147, 0.003091192320414569, 0.0060630421254768705, 0.0003045726327760146, 0.0003751250642932088, 0.001069141031378068, 0.0010243644662125005, 0.0002530861455519036, 0.00015772973630199765, 2.1392802540265595e-05, 0.00020213087340935145, 0.002272713328425485, 0.00035246546444782465, 0.0014249914752718675, 0.0022118120598437984, 0.001988923328132977, 0.00731108870080328, 0.008015160133215555, 0.0004289145559829845, 0.0006445890198519885, 0.0008609988559646546, 3.3560914748699445e-06, 0.002088375075253801, 1.7666457311104314e-06, 0.00019805374333275219, 0.000773815737604383, 0.0019493436056445368, 0.008494540248297395, 0.0018379828445085323, 0.0023501986546394147, 0.0011777507065365927, 0.008890001606954455, 0.009792204636007025, 0.00015063954409841847, 0.00014591000239149964, 0.0008573112631136886, 0.004975292060344295, 0.0009060259865155755, 0.00037012417683875506, 0.0004150899631759687, 0.00010040844480091414, 0.0019402802935689538, 0.0018144282902847328, 0.0008378641556195982, 0.002956328775876714, 0.0029009409581892995, 0.0023220036622930667, 0.0004443284284692191, 0.0037386938900850755, 0.0010433847243209045, 0.012056025842542362, 0.00013596217354313412, 0.0007988630801655684, 0.0018057093399080032, 0.00023318797636883877, 0.0004589285937442559, 4.976338936940783e-05, 0.008813523794575635, 0.015428051045771381, 0.0036027797153205966, 0.0013991407287465214, 0.002623434784963088, 0.0013382440437779745, 0.0005243142748976818, 0.006808962543757523, 0.0010040944983143018, 0.003985013942653484, 6.613164780796536e-06, 9.170751334666563e-05, 0.001833851754680479, 0.00304304188454651, 0.009930181115263254, 0.003142595069390478, 0.006632092399664792, 0.0008361439633591191, 3.383590638592924e-05, 0.000295021023901853, 0.0002773447880947918, 0.0005595423867119872, 0.0017096120376991616, 0.00014916232721385502, 5.229626778396641e-05, 0.0019771987719921238, 0.0011389376743265586, 0.0013571014367514522, 0.0019033146007564293, 0.004171606886829804, 6.572472223900166e-05, 0.009274403514514248, 0.0020823002724390445, 0.00045156898016332714, 5.306486015300542e-05, 0.0006749959229170333, 0.0018042083703915912, 0.00025098805548610714, 0.0001822979494349277, 1.8267578365732998e-05, 0.005447409509995043, 0.0046950390342855195, 0.0010920977531831955, 0.001699081034191291, 0.013060382365997932, 0.004070642637596705, 0.007100065603560734, 4.562378267925771e-05, 0.000145574616824 ...
# ['close', 'volume', 'open', 'high', 'low', 'middle', 'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos', 'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1', 'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2', 'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull', 'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr', 'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo', 'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
# ['CTAS_close', 'CTAS_volume', 'CTAS_open', 'CTAS_high', 'CTAS_low', 'CTAS_middle', 'CTAS_boll', 'CTAS_boll_ub', 'CTAS_boll_lb', 'CTAS_macd', 'CTAS_macds', 'CTAS_macdh', 'CTAS_pvo', 'CTAS_pvos', 'CTAS_pvoh', 'CTAS_ppo', 'CTAS_ppos', 'CTAS_ppoh', 'CTAS_qqe', 'CTAS_qqel', 'CTAS_qqes', 'CTAS_cr', 'CTAS_cr-ma1', 'CTAS_cr-ma2', 'CTAS_cr-ma3', 'CTAS_tr', 'CTAS_dx', 'CTAS_adx', 'CTAS_adxr', 'CTAS_log-ret', 'CTAS_wt1', 'CTAS_wt2', 'CTAS_supertrend_ub', 'CTAS_supertrend_lb', 'CTAS_supertrend', 'CTAS_bop', 'CTAS_cti', 'CTAS_eribull', 'CTAS_eribear', 'CTAS_rvgi', 'CTAS_rvgis', 'CTAS_kst', 'CTAS_ao', 'CTAS_aroon', 'CTAS_atr', 'CTAS_cci', 'CTAS_chop', 'CTAS_cmo', 'CTAS_coppock', 'CTAS_dma', 'CTAS_ichimoku', 'CTAS_inertia', 'CTAS_ftr', 'CTAS_kama', 'CTAS_kdjk', 'CTAS_kdjd', 'CTAS_kdjj', 'CTAS_ker', 'CTAS_mfi', 'CTAS_ndi', 'CTAS_pdi', 'CTAS_pgo', 'CTAS_psl', 'CTAS_rsi', 'CTAS_rsv', 'CTAS_stochrsi', 'CTAS_tema', 'CTAS_trix', 'CTAS_wr', 'CTAS_vr', 'CTAS_vwma']
# []
# **************************
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 0, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ffill(inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bfill(inplace=True)
# [0.002905075986892154, 0.0015327868805137834, 0.00024292377742782018, 6.714754249677019e-05, 3.738457895651136e-05, 0.0006347364676210273, 0.0003789787417846345, 0.0007216902352784061, 0.0012080921645862507, 0.0013896150385153698, 0.0022511359842974582, 0.0015364968915436673, 0.0043690971687278726, 0.006311330881950602, 0.002838104427854906, 0.0013492677852881788, 0.0014426126167053032, 0.002487174876624524, 0.00013929822771633648, 0.0016317427283765308, 0.0002825738654997015, 0.0005878820910703278, 0.001115645750653269, 0.0005159932237409192, 0.00035705044917389445, 0.0015627343773967275, 0.0019356281391120001, 0.0007918698300720098, 0.00030561674062725027, 0.0023449279165596018, 0.0010600352516730313, 0.0023226021857030823, 1.9911440058776812e-05, 0.002461900699967553, 0.0003612704750767967, 0.0018863157660414195, 0.0027712135500078294, 0.0014256184447296947, 0.0006418717164060333, 0.001500674396210171, 5.8887080311486296e-05, 4.488887397355758e-05, 5.5960499652759135e-05, 0.0001648517452552413, 0.00036336587854257884, 0.01169165203495932, 0.0032971505789401627, 0.005287865438695428, 0.0032224073823347, 0.003211702294776507, 0.001989196140573233, 0.0008680724404486935, 0.0032886802719291966, 0.0034478501022000064, 0.0005880519797824076, 0.011834581142740257, 0.003074559954204389, 0.006131971424752473, 0.0013616766324620094, 0.000543862029162057, 0.0030864658152678264, 0.001915206346495657, 0.0038473122497326784, 0.0014534418822181386, 0.0006204296807639449, 0.0033221364292408324, 0.00012548661390323802, 0.000749812730167517, 0.001278256056175627, 0.002615228938947312, 3.8507295664453785e-05, 0.0008884345339881793, 0.013413583802623131, 0.0002771898148210507, 0.0013573427033831726, 0.001479733044145781, 8.278656972528187e-05, 0.0007128877451384908, 0.0001222147499422837, 0.0001380618384576832, 0.0017388478810539515, 0.000768532339819158, 0.001382423855438223, 0.0009965288166575307, 0.0029162637474363187, 0.006489638837476265, 0.0016610949464048723, 0.0016894110341363487, 0.0018649522965774328, 0.00039500912290028943, 0.0005071327136870468, 0.0003582842326102171, 0.004968837683841374, 0.0017764403883873462, 0.00010164265842139603, 0.006365180714142578, 0.0021906336998813755, 0.004202247889358363, 0.0029277444606222217, 0.0011730539080199616, 0.0023227923608614906, 0.007495017672392452, 0.0025938139205919425, 8.4025489626644e-05, 2.83443615742407e-05, 4.1256271701294614e-05, 0.00266834511437398, 0.0034758601888163826, 0.0061182955265984456, 0.0022660315990085463, 0.005881488455093765, 0.0010167241995379796, 0.0010601362721739506, 0.0002503471053987707, 0.0011682194597607738, 0.00012355227939492421, 0.013234758664765528, 0.0027467493616577616, 0.005286739099371178, 0.0012331908501768299, 0.0018843668450136714, 0.0018184198474799763, 1.231482906023471e-05, 0.0020192952831425562, 0.0011183086005037912, 0.0002989697313674685, 8.844283776555326e-06, 0.006963671559712907, 0.0038523357501285688, 0.0022915882290485082, 0.0020111571772662984, 0.0004813443475732338, 0.0022901531209251723, 0.0004878911675259276, 0.002433934039538988, 0.00019862020476312485, 0.0013547152458449265, 0.003289407109697434, 0.0007449281394805066, 0.00018705204480102985, 0.00013475050057794007, 8.087067059015807e-05, 0.011287351494267106, 0.0008519406940832225, 0.011165042442289354, 0.0007493104537187798, 5.025606596774984e-05, 0.00031432831581482606, 0.0021289779402861807, 0.0002588365481704767, 0.00010439554495909954, 0.0013169172563575373, 0.00010267463940680376, 0.0003990301896284922, 0.004038159633897235, 0.0003617492596785681, 0.002439075768536478, 0.0004329745380803698, 0.0023064283069884686, 0.0009148840610518431, 0.00018386655238957696, 2.1367633021404372e-05, 0.00022447598244322497, 0.001064168291956092, 0.00021157344443668174, 0.00048293535474360026, 0.009001440983741164, 0.006800859198302024, 0.012163844999086949, 0.003198473834368714, 0.000596623916330396, 0.025833025815889383, 0.001784671461189945, 0.0001094054045483277, 6.567269385950108e-05, 9.65 ...
# ['close', 'volume', 'open', 'high', 'low', 'middle', 'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos', 'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1', 'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2', 'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull', 'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr', 'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo', 'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
# ['T_close', 'T_volume', 'T_open', 'T_high', 'T_low', 'T_middle', 'T_boll', 'T_boll_ub', 'T_boll_lb', 'T_macd', 'T_macds', 'T_macdh', 'T_pvo', 'T_pvos', 'T_pvoh', 'T_ppo', 'T_ppos', 'T_ppoh', 'T_qqe', 'T_qqel', 'T_qqes', 'T_cr', 'T_cr-ma1', 'T_cr-ma2', 'T_cr-ma3', 'T_tr', 'T_dx', 'T_adx', 'T_adxr', 'T_log-ret', 'T_wt1', 'T_wt2', 'T_supertrend_ub', 'T_supertrend_lb', 'T_supertrend', 'T_bop', 'T_cti', 'T_eribull', 'T_eribear', 'T_rvgi', 'T_rvgis', 'T_kst', 'T_ao', 'T_aroon', 'T_atr', 'T_cci', 'T_chop', 'T_cmo', 'T_coppock', 'T_dma', 'T_ichimoku', 'T_inertia', 'T_ftr', 'T_kama', 'T_kdjk', 'T_kdjd', 'T_kdjj', 'T_ker', 'T_mfi', 'T_ndi', 'T_pdi', 'T_pgo', 'T_psl', 'T_rsi', 'T_rsv', 'T_stochrsi', 'T_tema', 'T_trix', 'T_wr', 'T_vr', 'T_vwma']
# []
# **************************
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 0, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ffill(inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bfill(inplace=True)
# [0.005435342873434832, 0.010750414857252288, 0.002134227133297504, 0.004712865256085179, 0.0007588492427380941, 7.05754879545123e-05, 0.0016424427001293812, 0.005750391757469294, 0.0036422260441424242, 0.0021788882148968684, 0.0014783257440068448, 0.0018992243947798537, 0.0031740199790137045, 0.0015806226226549782, 0.00967422374178653, 0.00013217415922569582, 0.004739989230498194, 0.0025251992855519676, 0.0022154729645454674, 0.001458889940993979, 5.593230195969568e-05, 4.6293813169208387e-05, 6.208992008023723e-06, 0.0, 2.812302486181882e-05, 0.0063130050365382525, 0.003022298824546353, 0.0004580269522839177, 0.0014542313362396067, 0.005210056752162885, 0.0016499218394368281, 0.007775997500404209, 4.831639868857374e-06, 0.00016060926651081687, 1.5356141444245243e-05, 0.0016416132712047122, 0.005031908993414396, 0.0056381115373525335, 0.004081428055812375, 0.0004951877074617015, 0.001581477919289739, 0.00750184807805006, 0.000796504490076798, 0.0014035116723401385, 0.0014791716684434508, 0.004448461699768249, 0.002902890620705626, 0.004998014564093872, 0.0020758373996251933, 8.622092842699174e-05, 0.00519047848922459, 0.0001645904885809963, 0.005410639108377071, 0.0009963225827005727, 0.005549908245237998, 0.0014089465460570673, 0.004079718279676979, 0.005193034172332957, 0.0008302903201535759, 0.0006157394202203865, 0.001276915420967038, 0.004469661822273432, 0.0010936898183149589, 0.0023430144754103257, 0.0022137230536899985, 0.0004845099289112892, 0.005978635052157742, 0.0006410629505454827, 0.002719604464149656, 0.002599850496643256, 0.003075389317451411, 0.00310665087682312, 0.0029202029937237346, 0.001173990356709333, 0.001115667543436671, 0.004572827736673789, 0.0044893993893393505, 0.0023549570982560777, 0.0025181550270400826, 0.0004057101295226942, 0.0031555477614388615, 0.0013873496868959797, 0.002416150016309377, 0.006176935866987627, 0.0015468278815322755, 0.0022593348766314562, 0.0005072683157714734, 0.000650663774140472, 0.0014060846880263325, 0.003282920442833755, 0.00014556962120338513, 5.7340102756209754e-05, 6.7356747968597855e-09, 3.5228752527912706e-08, 1.3119907928146874e-05, 0.0014933088853414152, 0.006438513055098355, 0.007689331473126529, 0.0025926411033573024, 0.0013059340335607977, 0.003663382320959354, 0.0013126704432052298, 0.0001374973861084274, 0.0015655995889655373, 0.00039678113732041136, 1.1282937455860434e-06, 0.005225602924490411, 0.00021508989127958666, 0.004832320610825589, 0.0013009439450446185, 0.00026810601295213497, 0.0014169302105112107, 0.00012583878642870465, 4.573924859128772e-05, 0.001817029015246882, 0.0002843888862323307, 0.00456617057653457, 0.0006787418286169882, 0.0047682828859500846, 0.0009117241721531147, 0.0005876490422891536, 0.0012643628171005409, 0.0003118122381298158, 0.0005465898541730296, 0.0015296479515135182, 0.0009839868184465862, 0.0012130109599573999, 0.0024476476494693575, 0.010308735600146696, 0.00894738113234654, 0.0006052526894668607, 0.00381962737049623, 0.0007859156284640302, 0.0017527326319724365, 0.001101083120024555, 0.002005474294328477, 0.0004284842771815231, 0.0008916820970754082, 0.001586849176173588, 0.0003801719267690948, 0.0215274757275953, 0.0009583110007435932, 0.0018223084167480925, 0.002821139492030537, 0.0002616846300514793, 0.0002540362418460776, 0.03908208937646423, 0.0012731266095505982, 0.0006021349538562956, 0.000584166994404489, 0.015011490274580652, 0.0011944059402420367, 9.427759649026161e-05, 0.0013967127139633772, 0.0009885912314632219, 0.0005511872326348105, 0.002902529767068881, 0.005764341589712219, 0.0021373831658069017, 0.002563052518050199, 0.0019373500669248253, 0.0013053739232989693, 0.0018861632297695829, 0.0, 9.560171019707546e-05, 0.00023523836276822955, 0.0005190683432040086, 0.002003919917436788, 0.011192005100636216, 0.004061384536150876, 0.0005518800400868734, 0.0018892474458640355, 0.0013257525804695842, 0.0011227126718298822, 0.0006724047453322476, 1.0726181439804355e-05, 1.4399921325137207e-05, 0.01206172764456105, ...
# ['close', 'volume', 'open', 'high', 'low', 'middle', 'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos', 'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1', 'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2', 'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull', 'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr', 'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo', 'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
# ['CSCO_close', 'CSCO_volume', 'CSCO_open', 'CSCO_high', 'CSCO_low', 'CSCO_middle', 'CSCO_boll', 'CSCO_boll_ub', 'CSCO_boll_lb', 'CSCO_macd', 'CSCO_macds', 'CSCO_macdh', 'CSCO_pvo', 'CSCO_pvos', 'CSCO_pvoh', 'CSCO_ppo', 'CSCO_ppos', 'CSCO_ppoh', 'CSCO_qqe', 'CSCO_qqel', 'CSCO_qqes', 'CSCO_cr', 'CSCO_cr-ma1', 'CSCO_cr-ma2', 'CSCO_cr-ma3', 'CSCO_tr', 'CSCO_dx', 'CSCO_adx', 'CSCO_adxr', 'CSCO_log-ret', 'CSCO_wt1', 'CSCO_wt2', 'CSCO_supertrend_ub', 'CSCO_supertrend_lb', 'CSCO_supertrend', 'CSCO_bop', 'CSCO_cti', 'CSCO_eribull', 'CSCO_eribear', 'CSCO_rvgi', 'CSCO_rvgis', 'CSCO_kst', 'CSCO_ao', 'CSCO_aroon', 'CSCO_atr', 'CSCO_cci', 'CSCO_chop', 'CSCO_cmo', 'CSCO_coppock', 'CSCO_dma', 'CSCO_ichimoku', 'CSCO_inertia', 'CSCO_ftr', 'CSCO_kama', 'CSCO_kdjk', 'CSCO_kdjd', 'CSCO_kdjj', 'CSCO_ker', 'CSCO_mfi', 'CSCO_ndi', 'CSCO_pdi', 'CSCO_pgo', 'CSCO_psl', 'CSCO_rsi', 'CSCO_rsv', 'CSCO_stochrsi', 'CSCO_tema', 'CSCO_trix', 'CSCO_wr', 'CSCO_vr', 'CSCO_vwma']
# []
# **************************
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 0, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ffill(inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bfill(inplace=True)
# [0.0009611827109185751, 0.005515092371404228, 9.998226750095336e-05, 0.0006122400238430835, 3.859485244410586e-05, 0.00011531910891553868, 2.330685039900145e-05, 0.0020461317450714746, 0.004056855127617999, 0.0011563234645047844, 0.00014057984449140278, 0.0033868267679336454, 0.004073514997456554, 0.004255193324672052, 0.022957142354067282, 1.2833301828568406e-05, 0.00030175925472662236, 0.005175297798818483, 0.0018273313080598458, 0.0005415477279025478, 0.0036931036339103384, 0.0010656443100881213, 0.001732845401802902, 0.004357568791240547, 0.0007562526951947757, 0.013153761349684365, 0.0076893803591707634, 0.002543098025715546, 0.0039464806068031915, 0.008643141597512975, 0.001934782378695002, 0.0021128149902644128, 0.00016930297439373326, 6.609449059918307e-05, 1.7174932354084375e-05, 0.007911694882170198, 0.004219367166358672, 0.0015699890388970762, 0.0038443923713312733, 0.0002354539038461851, 0.0022578748444310156, 0.0013330452565474909, 0.0010962377989712508, 0.009547708556847044, 9.097943262653118e-05, 0.0023817207297507775, 0.0062401298678008655, 0.004602854354333208, 0.0038218597813691273, 0.0010279628737555322, 0.00673775488012293, 0.0012025546639211923, 0.0005313655220467511, 0.0007597505170859368, 0.0003404596094413559, 0.0025598232173453988, 0.0079192566464567, 0.009025330877314459, 0.016130583796403086, 0.0014971473001554947, 0.001317779071565997, 0.0029941546914036715, 0.00034250648621479143, 0.0001800034229316152, 0.0027747022601624155, 0.0030765290028042388, 1.9091207290259648e-05, 0.0024584671941315383, 0.00017108985868817043, 0.00241980818743021, 0.0004171770480942489, 0.0018701032010845762, 0.004261225585241459, 0.005033247754635076, 0.0012758686943601025, 0.0007543312426691666, 1.7026558265747306e-05, 0.0015423778878043996, 0.0016095527273460389, 0.0019069579392653492, 0.0025382299306715506, 0.002905137330145386, 0.0008931397782257376, 0.003740496372396296, 0.004588338082120962, 0.0027619596574064605, 0.00016354577042571375, 0.0011826716659534408, 0.0015657016097975485, 0.0035284730793325113, 0.00014011870345103652, 0.000996480889467034, 0.0012885091407781855, 0.00041196702402512494, 2.9344496685813378e-05, 0.003342037298667231, 0.005045526681123862, 0.003296552100071718, 0.003075902913744295, 0.0025948843111767432, 0.00395496317583615, 0.0040458166674709455, 0.00023942572483046134, 6.853433887228027e-06, 0.00031244913496076106, 0.00019565277829089334, 0.005501452170403947, 0.002225357708777953, 0.004055486868010777, 0.0013960595307381837, 0.0007579901496844588, 0.0009053631762653787, 0.001770771341959243, 0.0022622588021775766, 0.0017511014792491806, 7.493769506236682e-05, 0.002662567699785886, 0.0018351241051902535, 0.002043105385816926, 0.0027312434514364676, 0.00011607705025800141, 0.00267215186012722, 0.0007505340972220169, 0.0009843623231243698, 0.00018859674259648904, 0.0007166510992931712, 0.0008881312505301991, 0.00514426204969772, 0.011213205735213689, 0.005234861485485993, 0.000812568280561721, 0.0019082975342823785, 0.00023353856589205488, 0.0015627324042874608, 0.0028112140046747526, 0.0017627444236192405, 0.0018890081281042817, 0.0034761573879060668, 0.0002545123839698683, 0.001743633536727144, 0.004055410594696963, 0.006200699411243505, 0.0015373635255673131, 0.015678914925163066, 0.0004337586553245012, 0.003816928807143128, 0.0001912911649368902, 0.0003221916996808149, 0.001018155015598945, 0.00022345038601504446, 1.6478562102278623e-05, 0.0024900810685153088, 0.001475404422146736, 0.00021715299060701536, 0.009825937953189635, 0.0022891777352197487, 0.020538156427337993, 0.00021782184036873067, 0.0013659102607683229, 0.009187894732909017, 3.0465129717630823e-05, 0.0006599250936259883, 0.00015024083099406143, 0.00480584704469488, 0.000453541471712832, 0.000875293716869676, 5.227279943464992e-05, 0.0028035557657180533, 0.005191476904707662, 0.0013061934262834282, 0.0005832853989967416, 0.002220787101187323, 0.0007663815257603164, 0.00421188954497761, 7.170971041168565e-06, 1.267391785700951 ...
# ['close', 'volume', 'open', 'high', 'low', 'middle', 'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos', 'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1', 'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2', 'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull', 'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr', 'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo', 'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
# ['MRK_close', 'MRK_volume', 'MRK_open', 'MRK_high', 'MRK_low', 'MRK_middle', 'MRK_boll', 'MRK_boll_ub', 'MRK_boll_lb', 'MRK_macd', 'MRK_macds', 'MRK_macdh', 'MRK_pvo', 'MRK_pvos', 'MRK_pvoh', 'MRK_ppo', 'MRK_ppos', 'MRK_ppoh', 'MRK_qqe', 'MRK_qqel', 'MRK_qqes', 'MRK_cr', 'MRK_cr-ma1', 'MRK_cr-ma2', 'MRK_cr-ma3', 'MRK_tr', 'MRK_dx', 'MRK_adx', 'MRK_adxr', 'MRK_log-ret', 'MRK_wt1', 'MRK_wt2', 'MRK_supertrend_ub', 'MRK_supertrend_lb', 'MRK_supertrend', 'MRK_bop', 'MRK_cti', 'MRK_eribull', 'MRK_eribear', 'MRK_rvgi', 'MRK_rvgis', 'MRK_kst', 'MRK_ao', 'MRK_aroon', 'MRK_atr', 'MRK_cci', 'MRK_chop', 'MRK_cmo', 'MRK_coppock', 'MRK_dma', 'MRK_ichimoku', 'MRK_inertia', 'MRK_ftr', 'MRK_kama', 'MRK_kdjk', 'MRK_kdjd', 'MRK_kdjj', 'MRK_ker', 'MRK_mfi', 'MRK_ndi', 'MRK_pdi', 'MRK_pgo', 'MRK_psl', 'MRK_rsi', 'MRK_rsv', 'MRK_stochrsi', 'MRK_tema', 'MRK_trix', 'MRK_wr', 'MRK_vr', 'MRK_vwma']
# []
# **************************
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 0, inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ffill(inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/2306489379.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bfill(inplace=True)
# [0.0025366385608969234, 0.00944476424938544, 0.001245587804614741, 7.580047882385823e-05, 0.0031908294570261253, 0.00031342941989485055, 0.0007737733516243412, 0.0014641537108843275, 0.0009183255818837726, 0.00300427785310149, 0.0013150789918307377, 0.0026116264178582143, 0.004701266007429453, 0.0030925393997685135, 0.007682298876537155, 3.930810689076343e-05, 0.0010924320219680198, 0.001201625705039244, 0.0001225706285287653, 0.0011160979319974297, 0.00034618400040700346, 0.0002575864419429628, 0.002864353234395264, 0.001144854029356664, 0.00016113338562729154, 0.0012443609889293242, 0.0023850106993267605, 0.00023463941917775693, 0.006294605424240656, 0.009609118975682007, 3.580608815048345e-05, 0.00032768271921644707, 0.0005315723169335871, 1.0407576650612672e-05, 4.654809747383663e-05, 0.0054089249260516215, 0.00048077928763993436, 0.01757982519009759, 0.0010212677631716675, 0.0001526220619589951, 0.0002737504772929835, 0.00758943456815402, 0.003590019659801372, 0.007847681607228995, 0.00010498183335464124, 0.0028386970032417205, 0.0045055925551582224, 0.00150599620336518, 0.0024394226530812355, 0.0013221583594709304, 0.0018686091019011358, 0.0007416684027980304, 0.0014170630357020573, 4.6060400135517435e-06, 0.002847484700795896, 0.004303465576854942, 0.00015912459768000262, 0.005180651556282603, 0.0035646402436934283, 0.0002622900456050999, 0.002506514260620132, 0.0010125649761231687, 0.001731784387699527, 0.007090048246457781, 0.002211904235879638, 0.0036422180010792123, 0.006110402006232725, 0.0006388707389012449, 0.001919454089278021, 0.0002692008917322152, 0.0022250671862410745, 0.0037805895320765495, 0.007294085964573665, 0.0027440647620255837, 0.004483450971929489, 0.0002703268883301602, 0.00013709121520877335, 4.607920946985773e-05, 0.00018568069262525993, 0.002526347354602077, 0.00041454263322282916, 0.004438859208107795, 0.0004610319571878731, 0.0018186128696457775, 0.0018787835945074673, 0.002934383933745173, 0.005027469843926065, 0.0009646400587836525, 0.005014745506597705, 0.0020455198154017704, 9.333666172711518e-06, 3.322331627627288e-05, 0.005304177309797429, 0.00020313532980120735, 0.009613238879107403, 0.0008473322859125781, 0.0023581149397159562, 0.0029862116303335535, 0.00037748418681809586, 0.00011958373141135632, 0.004151959958121317, 0.0011347232900248633, 0.0007511616529116691, 4.8566877576383045e-05, 5.113744001579095e-05, 0.0038139766021481948, 0.004957596847984426, 0.00622854265375013, 0.00032860832674200794, 0.0017821698858134516, 0.000351527712547961, 0.0008444105945095863, 0.0007251618294098621, 7.630888950120291e-05, 0.001968364760765374, 0.00254809428906945, 0.002255804225172571, 0.006064614199158317, 0.002001616518232539, 0.0010644767942874958, 0.008656294217604454, 0.0022095749119672723, 0.0010516195080058604, 0.00017277700977436794, 0.0003897074600881991, 0.0006708663466343901, 0.0009404962429973775, 0.0019204929151211262, 0.01381864803439814, 0.005965378509179446, 0.0012667910612474925, 0.006946752292535242, 0.0016839411581345532, 0.0002009447704822527, 0.0020168357914202503, 0.0011036591377745226, 0.00046075065368948937, 0.0006013146154693783, 0.005051104745061924, 0.003798506231411632, 0.0017784747265053792, 0.0033675907343604754, 0.0011105626257620074, 0.004055316741731713, 0.00030585551304387025, 0.000356752094445053, 7.72721792896886e-05, 0.0013543655461636238, 0.001783685318156692, 0.0015694454373774932, 0.001637698988646591, 0.004836588738937253, 4.71998575213961e-05, 0.0006294793258647586, 0.006014410782927551, 0.0027859048968732858, 0.002634087376884026, 2.0369730425498156e-05, 0.00014251225482143603, 0.011398500171641757, 0.00028593480719497146, 0.0001105121734653723, 1.0697336296290114e-05, 0.00041940637171352665, 0.0014267710088528545, 0.018209442609628736, 0.001015152490608583, 0.0007240998148617782, 0.0032691892244171754, 0.00491131018122455, 0.0005798750982169702, 0.007663709055709504, 0.0006689680758362818, 0.0003576585625169392, 1.9942458808038e-05, 0.0002135019732468562 ...
# ['close', 'volume', 'open', 'high', 'low', 'middle', 'boll', 'boll_ub', 'boll_lb', 'macd', 'macds', 'macdh', 'pvo', 'pvos', 'pvoh', 'ppo', 'ppos', 'ppoh', 'qqe', 'qqel', 'qqes', 'cr', 'cr-ma1', 'cr-ma2', 'cr-ma3', 'tr', 'dx', 'adx', 'adxr', 'log-ret', 'wt1', 'wt2', 'supertrend_ub', 'supertrend_lb', 'supertrend', 'bop', 'cti', 'eribull', 'eribear', 'rvgi', 'rvgis', 'kst', 'ao', 'aroon', 'atr', 'cci', 'chop', 'cmo', 'coppock', 'dma', 'ichimoku', 'inertia', 'ftr', 'kama', 'kdjk', 'kdjd', 'kdjj', 'ker', 'mfi', 'ndi', 'pdi', 'pgo', 'psl', 'rsi', 'rsv', 'stochrsi', 'tema', 'trix', 'wr', 'vr', 'vwma']
#          Features BK_Relative_Importance CTAS_Relative_Importance  \
# 0            pvoh               0.000573                 0.002838
# 1             ker               0.016637                 0.006132
# 2          volume                0.00568                 0.001533
# 3             cci               0.009045                 0.011692
# 4              tr               0.005553                 0.001563
# 5         log-ret               0.001695                 0.002345
# 6         eribull               0.001233                 0.001426
# 7             cti               0.014317                 0.002771
# 8             mfi                0.00445                 0.001362
# 9              dx                 0.0097                 0.001936
# 10            wt2               0.010781                 0.002323
# 11            bop                0.00553                 0.001886
# 12           kdjd               0.001675                 0.011835
# 13          aroon               0.000914                 0.000165
# 14            pvo                0.00165                 0.004369
# 15            cmo               0.000673                 0.005288
# 16           chop               0.000086                 0.003297
# 17           pvos               0.001783                 0.006311
# 18            kst               0.000068                 0.000045
# 19       ichimoku               0.000566                 0.001989
# 20           kdjj               0.000936                 0.003075
# 21           adxr               0.003718                 0.000306
# 22            ftr                0.00457                 0.003289
# 23        eribear               0.005414                 0.000642
# 24        coppock               0.002052                 0.003222
# 25            rsi                0.00229                 0.001453
# 26             wr               0.007262                 0.001278
# 27       stochrsi               0.002563                 0.003322
# 28             ao               0.007495                 0.000056
# 29          macds               0.007827                 0.002251
# 30          close               0.001045                 0.002905
# 31           ppoh               0.001124                 0.002487
# 32           tema               0.000009                 0.000125
# 33            pgo               0.001671                 0.001915
# 34           ppos               0.004087                 0.001443
# 35         cr-ma2               0.005608                 0.000516
# 36            wt1               0.006065                  0.00106
# 37        boll_ub               0.000174                 0.000722
# 38            ppo               0.008471                 0.001349
# 39        boll_lb               0.000108                 0.001208
# 40             vr               0.001922                 0.002615
# 41           kdjk               0.000429                 0.000588
# 42          macdh               0.000096                 0.001536
# 43            pdi               0.001149                 0.003086
# 44            dma               0.003274                 0.003212
# 45            rsv                0.00083                  0.00062
# 46            adx               0.004354                 0.000792
# 47            ndi                0.00489                 0.000544
# 48           macd               0.000014                  0.00139
# 49            psl               0.000134                 0.003847
# 50           trix                0.00256                  0.00075
# 51           kama               0.001204                 0.003448
# 52           vwma               0.000458                 0.000039
# 53        inertia               0.003195                 0.000868
# 54           high                0.00046                 0.000067
# 55         cr-ma1               0.000128                 0.001116
# 56            qqe                 0.0011                 0.000139
# 57            low               0.001235                 0.000037
# 58           qqel               0.000207                 0.001632
# 59             cr               0.002738                 0.000588
# 60           open               0.000931                 0.000243
# 61           qqes               0.000136                 0.000283
# 62          rvgis               0.000123                 0.000059
# 63           boll               0.000085                 0.000379
# 64  supertrend_lb               0.000077                 0.002462
# 65           rvgi               0.000174                 0.001501
# 66            atr               0.000403                 0.000363
# 67         cr-ma3               0.000974                 0.000357
# 68         middle               0.000158                 0.000635
# 69     supertrend                0.00031                 0.000361
# 70  supertrend_ub               0.000006                  0.00002
#
#    T_Relative_Importance CSCO_Relative_Importance MRK_Relative_Importance  \
# 0               0.009674                 0.022957                0.007682
# 1               0.005193                 0.009025                0.005181
# 2                0.01075                 0.005515                0.009445
# 3               0.004448                 0.002382                0.002839
# 4               0.006313                 0.013154                0.001244
# 5                0.00521                 0.008643                0.009609
# 6               0.005638                  0.00157                 0.01758
# 7               0.005032                 0.004219                0.000481
# 8                0.00083                 0.016131                0.003565
# 9               0.003022                 0.007689                0.002385
# 10              0.007776                 0.002113                0.000328
# 11              0.001642                 0.007912                0.005409
# 12              0.001409                  0.00256                0.004303
# 13              0.001404                 0.009548                0.007848
# 14              0.003174                 0.004074                0.004701
# 15              0.004998                 0.004603                0.001506
# 16              0.002903                  0.00624                0.004506
# 17              0.001581                 0.004255                0.003093
# 18              0.007502                 0.001333                0.007589
# 19               0.00519                 0.006738                0.001869
# 20               0.00408                 0.007919                0.000159
# 21              0.001454                 0.003946                0.006295
# 22              0.005411                 0.000531                0.001417
# 23              0.004081                 0.003844                0.001021
# 24              0.002076                 0.003822                0.002439
# 25              0.002343                  0.00018                 0.00709
# 26               0.00272                 0.000171                0.001919
# 27              0.000485                 0.003077                0.003642
# 28              0.000797                 0.001096                 0.00359
# 29              0.001478                 0.000141                0.001315
# 30              0.005435                 0.000961                0.002537
# 31              0.002525                 0.005175                0.001202
# 32              0.005979                 0.000019                 0.00611
# 33               0.00447                 0.002994                0.001013
# 34               0.00474                 0.000302                0.001092
# 35                   0.0                 0.004358                0.001145
# 36               0.00165                 0.001935                0.000036
# 37               0.00575                 0.002046                0.001464
# 38              0.000132                 0.000013                0.000039
# 39              0.003642                 0.004057                0.000918
# 40                0.0026                  0.00242                0.000269
# 41               0.00555                  0.00034                0.002847
# 42              0.001899                 0.003387                0.002612
# 43              0.001277                 0.001318                0.002507
# 44              0.000086                 0.001028                0.001322
# 45              0.002214                 0.002775                0.002212
# 46              0.000458                 0.002543                0.000235
# 47              0.000616                 0.001497                0.000262
# 48              0.002179                 0.001156                0.003004
# 49              0.001094                 0.000343                0.001732
# 50              0.000641                 0.002458                0.000639
# 51              0.000996                  0.00076                0.000005
# 52              0.003075                 0.000417                0.002225
# 53              0.000165                 0.001203                0.000742
# 54              0.004713                 0.000612                0.000076
# 55              0.000006                 0.001733                0.002864
# 56              0.002215                 0.001827                0.000123
# 57              0.000759                 0.000039                0.003191
# 58              0.001459                 0.000542                0.001116
# 59              0.000046                 0.001066                0.000258
# 60              0.002134                   0.0001                0.001246
# 61              0.000056                 0.003693                0.000346
# 62              0.001581                 0.002258                0.000274
# 63              0.001642                 0.000023                0.000774
# 64              0.000161                 0.000066                 0.00001
# 65              0.000495                 0.000235                0.000153
# 66              0.001479                 0.000091                0.000105
# 67              0.000028                 0.000756                0.000161
# 68              0.000071                 0.000115                0.000313
# 69              0.000015                 0.000017                0.000047
# 70              0.000005                 0.000169                0.000532
#
#     Average_relative_Importance
# 0                      0.008745
# 1                      0.008434
# 2                      0.006585
# 3                      0.006081
# 4                      0.005565
# 5                      0.005500
# 6                      0.005489
# 7                      0.005364
# 8                      0.005267
# 9                      0.004946
# 10                     0.004664
# 11                     0.004476
# 12                     0.004356
# 13                     0.003976
# 14                     0.003593
# 15                     0.003414
# 16                     0.003406
# 17                     0.003405
# 18                     0.003307
# 19                     0.003270
# 20                     0.003234
# 21                     0.003144
# 22                     0.003044
# 23                     0.003001
# 24                     0.002722
# 25                     0.002671
# 26                     0.002670
# 27                     0.002618
# 28                     0.002607
# 29                     0.002602
# 30                     0.002577
# 31                     0.002503
# 32                     0.002449
# 33                     0.002413
# 34                     0.002333
# 35                     0.002325
# 36                     0.002149
# 37                     0.002031
# 38                     0.002001
# 39                     0.001987
# 40                     0.001965
# 41                     0.001951
# 42                     0.001906
# 43                     0.001867
# 44                     0.001784
# 45                     0.001730
# 46                     0.001676
# 47                     0.001562
# 48                     0.001549
# 49                     0.001430
# 50                     0.001410
# 51                     0.001282
# 52                     0.001243
# 53                     0.001234
# 54                     0.001186
# 55                     0.001169
# 56                     0.001081
# 57                     0.001052
# 58                     0.000991
# 59                     0.000939
# 60                     0.000931
# 61                     0.000903
# 62                     0.000859
# 63                     0.000581
# 64                     0.000555
# 65                     0.000512
# 66                     0.000488
# 67                     0.000455
# 68                     0.000258
# 69                     0.000150
# 70                     0.000146

# %%
imp_features=list(feat_importance_all['Features'][:15])
imp_features
# feat_importance_all
# Out:
# ['pvoh',
#  'ker',
#  'volume',
#  'cci',
#  'tr',
#  'log-ret',
#  'eribull',
#  'cti',
#  'mfi',
#  'dx',
#  'wt2',
#  'bop',
#  'kdjd',
#  'aroon',
#  'pvo']

# %%
imp_features.append('close') if 'close' not in imp_features else imp_features
final_col_names = []
for col in imp_features:
    for ticker in tickers:
        final_col_names.append(f'{ticker}_{col}')

print(final_col_names)
# Out:
# ['BK_pvoh', 'CTAS_pvoh', 'T_pvoh', 'CSCO_pvoh', 'MRK_pvoh', 'BK_ker', 'CTAS_ker', 'T_ker', 'CSCO_ker', 'MRK_ker', 'BK_volume', 'CTAS_volume', 'T_volume', 'CSCO_volume', 'MRK_volume', 'BK_cci', 'CTAS_cci', 'T_cci', 'CSCO_cci', 'MRK_cci', 'BK_tr', 'CTAS_tr', 'T_tr', 'CSCO_tr', 'MRK_tr', 'BK_log-ret', 'CTAS_log-ret', 'T_log-ret', 'CSCO_log-ret', 'MRK_log-ret', 'BK_eribull', 'CTAS_eribull', 'T_eribull', 'CSCO_eribull', 'MRK_eribull', 'BK_cti', 'CTAS_cti', 'T_cti', 'CSCO_cti', 'MRK_cti', 'BK_mfi', 'CTAS_mfi', 'T_mfi', 'CSCO_mfi', 'MRK_mfi', 'BK_dx', 'CTAS_dx', 'T_dx', 'CSCO_dx', 'MRK_dx', 'BK_wt2', 'CTAS_wt2', 'T_wt2', 'CSCO_wt2', 'MRK_wt2', 'BK_bop', 'CTAS_bop', 'T_bop', 'CSCO_bop', 'MRK_bop', 'BK_kdjd', 'CTAS_kdjd', 'T_kdjd', 'CSCO_kdjd', 'MRK_kdjd', 'BK_aroon', 'CTAS_aroon', 'T_aroon', 'CSCO_aroon', 'MRK_aroon', 'BK_pvo', 'CTAS_pvo', 'T_pvo', 'CSCO_pvo', 'MRK_pvo', 'BK_close', 'CTAS_close', 'T_close', 'CSCO_close', 'MRK_close']

# %%
final_col_names=final_col_names+['10y2y_spread','10y3m_spread','3m_rate','ltiit']

# %%
model_data=final_df[['Date']+final_col_names]

model_data.fillna(method='ffill',inplace=True)
model_data.fillna(method='bfill',inplace=True)

for ticker in tickers:
    model_data[ticker+"_close"] = model_data[ticker+"_close"].pct_change()
#     print(model_data)
model_data=model_data.loc[14:]

model_data=model_data.set_index('Date')
model_data
# Out:
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/1422420579.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data.fillna(method='ffill',inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/1422420579.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data.fillna(method='bfill',inplace=True)
# /var/folders/dk/mxqr91nj7135zkb7ptp3mq5c0000gn/T/ipykernel_30825/1422420579.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data[ticker+"_close"] = model_data[ticker+"_close"].pct_change()
#              BK_pvoh  CTAS_pvoh    T_pvoh  CSCO_pvoh  MRK_pvoh    BK_ker  \
# Date
# 2007-04-30 -0.083387  -2.201453  0.455490   1.076616  0.110688  0.183112
# 2007-05-07 -2.037179  -3.938990 -1.055542   1.390336 -2.171230  0.076397
# 2007-05-14 -1.202089  -6.334022 -0.448169   1.984144 -2.809539  0.294183
# 2007-05-21  4.211576   0.093183  0.835291   1.402640  2.187237  0.157842
# 2007-06-04  2.816598   7.306574 -1.496062  -0.262701  2.641894  0.159260
# ...              ...        ...       ...        ...       ...       ...
# 2022-06-06 -6.517010  -5.398720 -8.547998  -2.206432 -2.279928  0.448558
# 2022-06-13 -3.636337  -1.600125 -6.258412   0.915140 -0.850439  0.620489
# 2022-06-27 -5.482660  -3.805689 -7.224570   0.865236  0.104545  0.385041
# 2022-07-11 -7.696791  -3.063595 -8.725447  -1.483599 -0.628479  0.381952
# 2022-07-18 -5.939962  -0.627544 -9.558469  -2.490045 -1.531653  0.206819
#
#             CTAS_ker     T_ker  CSCO_ker   MRK_ker  ...   MRK_pvo  BK_close  \
# Date                                                ...
# 2007-04-30  0.411111  0.276729  0.150376  0.749876  ...  2.145314 -0.012683
# 2007-05-07  0.292621  0.306897  0.093597  0.749058  ... -0.699208  0.022727
# 2007-05-14  0.106110  0.678986  0.142367  0.788591  ... -2.060244 -0.016183
# 2007-05-21  0.325417  0.637184  0.043977  0.811965  ...  3.495938 -0.015222
# 2007-06-04  0.002770  0.627299  0.124342  0.647241  ...  4.623184  0.004487
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-06-06  0.054146  0.825744  0.590000  0.509452  ... -7.783892  0.028424
# 2022-06-13  0.461091  0.387620  0.617133  0.158911  ... -6.567013 -0.097497
# 2022-06-27  0.309893  0.469301  0.634199  0.368243  ... -5.585892  0.038341
# 2022-07-11  0.249000  0.335333  0.577519  0.293897  ... -6.476036 -0.031352
# 2022-07-18  0.233278  0.283015  0.545900  0.233106  ... -7.762123  0.025414
#
#             CTAS_close   T_close  CSCO_close  MRK_close  10y2y_spread  \
# Date
# 2007-04-30   -0.006364 -0.026402    0.006020  -0.004451          0.03
# 2007-05-07    0.030958  0.022727    0.040015   0.011470         -0.04
# 2007-05-14   -0.019674  0.010859   -0.054657   0.000961         -0.04
# 2007-05-21   -0.011090  0.012990    0.004184   0.032835         -0.02
# 2007-06-04    0.068357  0.008631    0.023106  -0.037925         -0.04
# ...                ...       ...         ...        ...           ...
# 2022-06-06    0.073296  0.009643    0.045675  -0.042524          0.31
# 2022-06-13   -0.099567 -0.056351   -0.046106  -0.053873          0.03
# 2022-06-27    0.061646  0.051619    0.012257   0.119796          0.12
# 2022-07-11    0.002264  0.007468   -0.002987  -0.001165         -0.08
# 2022-07-18   -0.004832 -0.006292   -0.015029  -0.020785         -0.19
#
#             10y3m_spread  3m_rate  ltiit
# Date
# 2007-04-30         -0.28     4.79   2.29
# 2007-05-07         -0.25     4.77   2.35
# 2007-05-14         -0.16     4.73   2.41
# 2007-05-21         -0.09     4.76   2.48
# 2007-06-04          0.12     4.68   2.51
# ...                  ...      ...    ...
# 2022-06-06          1.78     1.23   0.75
# 2022-06-13          1.70     1.69   1.04
# 2022-06-27          1.41     1.75   1.03
# 2022-07-11          0.81     2.13   1.16
# 2022-07-18          0.46     2.13   1.16
#
# [721 rows x 84 columns]

# %%
class WindowGenerator():
    """This class takes time series data that is in a sequential format, transforming
    it into pairs of inputs and labels, so that the inputs are windows of consecutive
    samples from the data.
    """
    def __init__(self,input_width=5,label_width=1,shift=1, train_df=None, val_df=None,
                 test_df=None, label_columns=None,batch_size=None,shuffle=False):
        """This method initiates the WindowGenerator class.

        Inputs:
        -------
        input_width (int, default=5): the width of the window, which represents the 
            amount of time steps from the earliest input observation to the last.
        label_width (int, default=1): the width of the label. This determines the amount
             of time steps that will be predicted.
        shift (int, default=1): jump between the last input in the window and the first 
            label.
        train_df (pandas Dataframe, default=None): array-like object containing the train 
            data which comes in a time series format.
        val_df (pandas Dataframe, default=None): array-like object containing the 
            validation data.
        test_df (pandas Dataframe, default=None): array-like object containing the test 
            data.
        label_columns (list|string, default=None): name of the column(s) that are used 
            as labels.
        batch_size (int, deafault=None): the size of the batches of the tf.data.Dataset
            object (whose dimensions are (batch,input_width,features) for the input and
            (batch,label_width,label_columns) for the labels).
        shuffle (boolean, default=False): determines if the data inside the tf.data.Dataset
            is shuffled.
        
        Outputs:
        --------
        None
        """
        # Define attributes of the class:
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        self.label_columns = label_columns
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        self.batch_size = batch_size
        self.shuffle = shuffle

        # Define information about columns:
        if isinstance(label_columns,type(None)):
            self.label_columns_indices = {name:i for i,name in enumerate(label_columns)}
        self.column_indices = {name:i for i,name in enumerate(train_df.columns)}

        # Define window information:
        self.total_window_size = input_width+shift
        self.input_slice = slice(0,input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size-self.label_width
        self.labels_slice = slice(self.label_start,None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def __repr__(self):
        """This method determines what is returned when an instance of the object
        is called
        """
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'
        ])
    
    def split_window(self, features):
        """This method converts a list of consecutive inputs to a window of
        inputs and a window of labels.

        Inputs:
        -------
        features (pandas Dataset): features in the dataframe

        Outputs:
        --------
        inputs ()
        """
        inputs = features[:, self.input_slice,:]
        labels = features[:,self.labels_slice,:]
        if not isinstance(self.label_columns,type(None)):
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis = -1
            )
        
        # Set the shapes of the informaiton:
        inputs.set_shape([None,self.input_width,None])
        labels.set_shape([None,self.label_width,None])

        return inputs,labels
    
    def make_dataset(self,data):
        """This method takes a time series DataFrame and convert it to a 
        tf.data.Dataset of (input_window,label_window) pairs, using the
        tf.keras.preprocessing.timeseries_dataset_from_array function.

        Input:
        ------
        data (pandas DataFrame): dataframe containing the time series information
            of the inputs and labels, which will transformed into windows and then 
            a tf.Dataset object.
        
        Outputs:
        --------

        """
        data = np.array(data,dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data = data,
            targets = None,
            sequence_length = self.total_window_size,
            sequence_stride = 1,
            shuffle = self.shuffle,
            batch_size = self.batch_size
        )
        ds = ds.map(self.split_window)
        print("************************************************")
        print(ds)

        return ds

    # Adding properties for accessing the train, val and test as tf.data.Dataset objects
    @property
    def train(self):
        if isinstance(self.train_df,type(None)):
            return None
        else:
            return self.make_dataset(self.train_df)
        print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")    
        print(self.train_df)

    @property
    def val(self):
        if isinstance(self.val_df,type(None)):
            return None
        else:
            return self.make_dataset(self.val_df)

    @property
    def test(self):
        if isinstance(self.test_df,type(None)):
            return None
        else:
            return self.make_dataset(self.test_df)

# %%
label_cols=[col for col in model_data.columns if "close" in col ]
label_cols
# Out:
# ['BK_close', 'CTAS_close', 'T_close', 'CSCO_close', 'MRK_close']

# %%
# Define train (70%), val (20%) and test (10%) dataframes: 
train_p, val_p, test_p = 0.7,0.2,0.1
window_size = 5
num_features = model_data.shape[1]
total_size = len(model_data)
train_size = int(total_size*train_p)
val_size = int(total_size*val_p)
test_size = int(total_size*test_p)
train_df = model_data.iloc[:train_size,:]
val_df = model_data.iloc[train_size-window_size:train_size+val_size,:]
test_df = model_data.iloc[train_size+val_size-window_size:,:]

# %%
model_data.columns
# Out:
# Index(['BK_pvoh', 'CTAS_pvoh', 'T_pvoh', 'CSCO_pvoh', 'MRK_pvoh', 'BK_ker',
#        'CTAS_ker', 'T_ker', 'CSCO_ker', 'MRK_ker', 'BK_volume', 'CTAS_volume',
#        'T_volume', 'CSCO_volume', 'MRK_volume', 'BK_cci', 'CTAS_cci', 'T_cci',
#        'CSCO_cci', 'MRK_cci', 'BK_tr', 'CTAS_tr', 'T_tr', 'CSCO_tr', 'MRK_tr',
#        'BK_log-ret', 'CTAS_log-ret', 'T_log-ret', 'CSCO_log-ret',
#        'MRK_log-ret', 'BK_eribull', 'CTAS_eribull', 'T_eribull',
#        'CSCO_eribull', 'MRK_eribull', 'BK_cti', 'CTAS_cti', 'T_cti',
#        'CSCO_cti', 'MRK_cti', 'BK_mfi', 'CTAS_mfi', 'T_mfi', 'CSCO_mfi',
#        'MRK_mfi', 'BK_dx', 'CTAS_dx', 'T_dx', 'CSCO_dx', 'MRK_dx', 'BK_wt2',
#        'CTAS_wt2', 'T_wt2', 'CSCO_wt2', 'MRK_wt2', 'BK_bop', 'CTAS_bop',
#        'T_bop', 'CSCO_bop', 'MRK_bop', 'BK_kdjd', 'CTAS_kdjd', 'T_kdjd',
#        'CSCO_kdjd', 'MRK_kdjd', 'BK_aroon', 'CTAS_aroon', 'T_aroon',
#        'CSCO_aroon', 'MRK_aroon', 'BK_pvo', 'CTAS_pvo', 'T_pvo', 'CSCO_pvo',
#        'MRK_pvo', 'BK_close', 'CTAS_close', 'T_close', 'CSCO_close',
#        'MRK_close', '10y2y_spread', '10y3m_spread', '3m_rate', 'ltiit'],
#       dtype='object')

# %%
model_data
# Out:
#              BK_pvoh  CTAS_pvoh    T_pvoh  CSCO_pvoh  MRK_pvoh    BK_ker  \
# Date
# 2007-04-30 -0.083387  -2.201453  0.455490   1.076616  0.110688  0.183112
# 2007-05-07 -2.037179  -3.938990 -1.055542   1.390336 -2.171230  0.076397
# 2007-05-14 -1.202089  -6.334022 -0.448169   1.984144 -2.809539  0.294183
# 2007-05-21  4.211576   0.093183  0.835291   1.402640  2.187237  0.157842
# 2007-06-04  2.816598   7.306574 -1.496062  -0.262701  2.641894  0.159260
# ...              ...        ...       ...        ...       ...       ...
# 2022-06-06 -6.517010  -5.398720 -8.547998  -2.206432 -2.279928  0.448558
# 2022-06-13 -3.636337  -1.600125 -6.258412   0.915140 -0.850439  0.620489
# 2022-06-27 -5.482660  -3.805689 -7.224570   0.865236  0.104545  0.385041
# 2022-07-11 -7.696791  -3.063595 -8.725447  -1.483599 -0.628479  0.381952
# 2022-07-18 -5.939962  -0.627544 -9.558469  -2.490045 -1.531653  0.206819
#
#             CTAS_ker     T_ker  CSCO_ker   MRK_ker  ...   MRK_pvo  BK_close  \
# Date                                                ...
# 2007-04-30  0.411111  0.276729  0.150376  0.749876  ...  2.145314 -0.012683
# 2007-05-07  0.292621  0.306897  0.093597  0.749058  ... -0.699208  0.022727
# 2007-05-14  0.106110  0.678986  0.142367  0.788591  ... -2.060244 -0.016183
# 2007-05-21  0.325417  0.637184  0.043977  0.811965  ...  3.495938 -0.015222
# 2007-06-04  0.002770  0.627299  0.124342  0.647241  ...  4.623184  0.004487
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-06-06  0.054146  0.825744  0.590000  0.509452  ... -7.783892  0.028424
# 2022-06-13  0.461091  0.387620  0.617133  0.158911  ... -6.567013 -0.097497
# 2022-06-27  0.309893  0.469301  0.634199  0.368243  ... -5.585892  0.038341
# 2022-07-11  0.249000  0.335333  0.577519  0.293897  ... -6.476036 -0.031352
# 2022-07-18  0.233278  0.283015  0.545900  0.233106  ... -7.762123  0.025414
#
#             CTAS_close   T_close  CSCO_close  MRK_close  10y2y_spread  \
# Date
# 2007-04-30   -0.006364 -0.026402    0.006020  -0.004451          0.03
# 2007-05-07    0.030958  0.022727    0.040015   0.011470         -0.04
# 2007-05-14   -0.019674  0.010859   -0.054657   0.000961         -0.04
# 2007-05-21   -0.011090  0.012990    0.004184   0.032835         -0.02
# 2007-06-04    0.068357  0.008631    0.023106  -0.037925         -0.04
# ...                ...       ...         ...        ...           ...
# 2022-06-06    0.073296  0.009643    0.045675  -0.042524          0.31
# 2022-06-13   -0.099567 -0.056351   -0.046106  -0.053873          0.03
# 2022-06-27    0.061646  0.051619    0.012257   0.119796          0.12
# 2022-07-11    0.002264  0.007468   -0.002987  -0.001165         -0.08
# 2022-07-18   -0.004832 -0.006292   -0.015029  -0.020785         -0.19
#
#             10y3m_spread  3m_rate  ltiit
# Date
# 2007-04-30         -0.28     4.79   2.29
# 2007-05-07         -0.25     4.77   2.35
# 2007-05-14         -0.16     4.73   2.41
# 2007-05-21         -0.09     4.76   2.48
# 2007-06-04          0.12     4.68   2.51
# ...                  ...      ...    ...
# 2022-06-06          1.78     1.23   0.75
# 2022-06-13          1.70     1.69   1.04
# 2022-06-27          1.41     1.75   1.03
# 2022-07-11          0.81     2.13   1.16
# 2022-07-18          0.46     2.13   1.16
#
# [721 rows x 84 columns]

# %%
# Define the batch size:
batch_size = 200

# Create an instance of the WindowGenerator object:
my_window = WindowGenerator(input_width=window_size,label_width=1,shift=1,train_df=train_df,val_df=val_df,
                            test_df=test_df,label_columns=label_cols,
                            batch_size=batch_size,shuffle=True)
print(my_window)

# Print the shapes for one batch of each sub dataset:
for example_inputs, example_labels in my_window.train.take(1):
    print("Train input shape:",example_inputs.shape)
    print("Train target shape:",example_labels.shape)
for example_inputs, example_labels in my_window.val.take(1):
    print("Validation input shape:",example_inputs.shape)
    print("Validation target shape:",example_labels.shape)
for example_inputs, example_labels in my_window.test.take(1):
    print("Test input shape:",example_inputs.shape)
    print("Test target shape:",example_labels.shape)
# Out:
# Total window size: 6
# Input indices: [0 1 2 3 4]
# Label indices: [5]
# Label column name(s): ['BK_close', 'CTAS_close', 'T_close', 'CSCO_close', 'MRK_close']
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# Train input shape: (200, 5, 84)
# Train target shape: (200, 1, 5)
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# Validation input shape: (144, 5, 84)
# Validation target shape: (144, 1, 5)
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# Test input shape: (73, 5, 84)
# Test target shape: (73, 1, 5)

# %%
num_features
# Out:
# 84

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dense, Conv1D, LSTM, GRU, Input, BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

from tensorflow.keras.callbacks import LearningRateScheduler
import numpy as np

# %%
my_window.train
# Out:
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,          # Stop training after no improvement for 10 epochs
restore_best_weights=False,  # Restore the best weights when stopping
min_delta=0.0001)

checkpont_rnn = ModelCheckpoint(
    filepath='best_model_weekly_multiple_features',
    save_weights_only=False,
    save_freq = 'epoch',
    monitor = 'val_loss',
    mode='min',
    save_best_only = True,
    verbose = 1)

# Initialize lists to store loss and learning rates
losses = []
learning_rates = []

# Custom callback to log loss and learning rate
class LossLearningRateCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        loss = logs['loss']
        learning_rates.append(lr)
#         print(learning_rates)
        losses.append(loss)
        print()
        print(f"Epoch {epoch+1}: Learning Rate = {lr.numpy()}, Loss = {loss}")
# 

# Create an instance of the custom callback
loss_lr_callback = LossLearningRateCallback()

def build_model(initial_lr=0.001):
    model_1 = Sequential([
    BatchNormalization(
        input_shape = (window_size,num_features),
        name = 'Batch_Norm_1'),
    LSTM(512,return_sequences=True,name='LSTM_1'),
    LSTM(512,name='LSTM_2'),
    Dense(256,activation='relu',name='Dense_1'),
    Dense(len(tickers),name='Returns')
])
    optimizer = Adam(learning_rate=initial_lr)
    
    model_1.compile(
    loss=tf.keras.losses.Huber(),
    metrics=[tf.metrics.RootMeanSquaredError(),'mae'],
    optimizer=optimizer)
    
    return model_1


def lr_schedule(epoch, initial_lr=0.01, decay_factor=0.9, decay_epochs=10):
    if epoch<decay_epochs:
        return initial_lr
    elif epoch%decay_epochs!=0:
        return initial_lr
    else:
        return initial_lr * (decay_factor ** (epoch // decay_epochs))

# learning schedule callback
lr_rate = LearningRateScheduler(lr_schedule)
callbacks_list = [lr_rate,loss_lr_callback, early_stopping, checkpont_rnn]
callbacks_list



# Define a list to store validation losses for each learning rate


# List of initial learning rates to try
initial_learning_rates = [0.001]
best_model = None
best_val_loss = float('inf')
validation_losses = []
num_epochs=100
for lr in initial_learning_rates:
    
    print(f"\nTraining with initial learning rate: {lr}")
    model_1 = build_model(initial_lr=lr)
    print(model_1.summary())

    history = model_1.fit(my_window.train,
                          epochs=num_epochs,
                          callbacks=callbacks_list,
                          verbose=1,
                          validation_data=my_window.val)
    
    # Get the final validation loss for this learning rate
    # Get the final validation loss for this learning rate
    final_val_loss = history.history['val_loss'][-1]
    validation_losses.append(final_val_loss)

    last_epoch = len(history.history['loss'])
    # Plot learning rate vs. epoch
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.plot(range(len(history.history['loss'])), history.history['lr'])
    plt.xlabel('Epoch')
    plt.ylabel('Learning Rate')
    plt.title(f'Learning Rate Schedule (Initial LR = {lr})')

    # Plot epoch vs. loss
    plt.subplot(1, 3, 2)
    plt.plot(range(len(history.history['loss'])), history.history['loss'], label='Training Loss')
    plt.plot(range(len(history.history['loss'])), history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'Loss vs. Epoch (Initial LR = {lr})')

    # Plot epoch vs. validation loss
    plt.subplot(1, 3, 3)
    plt.plot(range(len(history.history['loss'])), history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.title(f'Validation Loss vs. Epoch (Initial LR = {lr})')

    plt.tight_layout()
    plt.show()
    
    # Check if this model has the best validation loss
    if final_val_loss < best_val_loss:
        best_lr = lr
        best_val_loss = final_val_loss
        best_model = model_1

# Save the best model
if best_model is not None:
    best_model.save('best_model_weekly_multiple_features.h5')
# Out:
# Training with initial learning rate: 0.001
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Batch_Norm_1 (BatchNormali  (None, 5, 84)             336
#  zation)
#
#  LSTM_1 (LSTM)               (None, 5, 512)            1222656
#
#  LSTM_2 (LSTM)               (None, 512)               2099200
#
#  Dense_1 (Dense)             (None, 256)               131328
#
#  Returns (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3454805 (13.18 MB)
# Trainable params: 3454637 (13.18 MB)
# Non-trainable params: 168 (672.00 Byte)
# _________________________________________________________________
# None
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# Epoch 1/100
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0058 - root_mean_squared_error: 0.1080 - mae: 0.0823
# Epoch 1: Learning Rate = 0.0010000000474974513, Loss = 0.005457867868244648
#
# Epoch 1: val_loss improved from inf to 0.00604, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 3s 1s/step - loss: 0.0055 - root_mean_squared_error: 0.1061 - mae: 0.0807 - val_loss: 0.0060 - val_root_mean_squared_error: 0.1099 - val_mae: 0.0868 - lr: 0.0010
# Epoch 2/100
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0025 - root_mean_squared_error: 0.0713 - mae: 0.0555
# Epoch 2: Learning Rate = 0.0010000000474974513, Loss = 0.002431734697893262
#
# Epoch 2: val_loss improved from 0.00604 to 0.00389, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 927ms/step - loss: 0.0024 - root_mean_squared_error: 0.0704 - mae: 0.0549 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0882 - val_mae: 0.0700 - lr: 0.0010
# Epoch 3/100
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0585 - mae: 0.0442
# Epoch 3: Learning Rate = 0.0010000000474974513, Loss = 0.001645372249186039
#
# Epoch 3: val_loss improved from 0.00389 to 0.00347, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 938ms/step - loss: 0.0016 - root_mean_squared_error: 0.0579 - mae: 0.0438 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0833 - val_mae: 0.0661 - lr: 0.0010
# Epoch 4/100
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0522 - mae: 0.0394
# Epoch 4: Learning Rate = 0.0010000000474974513, Loss = 0.0013281721621751785
#
# Epoch 4: val_loss improved from 0.00347 to 0.00344, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 930ms/step - loss: 0.0013 - root_mean_squared_error: 0.0518 - mae: 0.0391 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0830 - val_mae: 0.0666 - lr: 0.0010
# Epoch 5/100
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0476 - mae: 0.0349
# Epoch 5: Learning Rate = 0.0010000000474974513, Loss = 0.0011435517808422446
#
# Epoch 5: val_loss improved from 0.00344 to 0.00327, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 971ms/step - loss: 0.0011 - root_mean_squared_error: 0.0477 - mae: 0.0351 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0809 - val_mae: 0.0656 - lr: 0.0010
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0454 - mae: 0.0328
# Epoch 6: Learning Rate = 0.0010000000474974513, Loss = 0.0010182021651417017
#
# Epoch 6: val_loss improved from 0.00327 to 0.00312, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 869ms/step - loss: 0.0010 - root_mean_squared_error: 0.0454 - mae: 0.0328 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0791 - val_mae: 0.0631 - lr: 0.0010
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 9.8214e-04 - root_mean_squared_error: 0.0441 - mae: 0.0316
# Epoch 7: Learning Rate = 0.0010000000474974513, Loss = 0.0009821413550525904
#
# Epoch 7: val_loss improved from 0.00312 to 0.00282, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 970ms/step - loss: 9.8214e-04 - root_mean_squared_error: 0.0441 - mae: 0.0316 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0751 - val_mae: 0.0597 - lr: 0.0010
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - loss: 9.2301e-04 - root_mean_squared_error: 0.0432 - mae: 0.0305
# Epoch 8: Learning Rate = 0.0010000000474974513, Loss = 0.0009230136638507247
#
# Epoch 8: val_loss improved from 0.00282 to 0.00238, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 942ms/step - loss: 9.2301e-04 - root_mean_squared_error: 0.0432 - mae: 0.0305 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0690 - val_mae: 0.0548 - lr: 0.0010
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - loss: 8.8196e-04 - root_mean_squared_error: 0.0417 - mae: 0.0292
# Epoch 9: Learning Rate = 0.0010000000474974513, Loss = 0.0008819600916467607
#
# Epoch 9: val_loss improved from 0.00238 to 0.00235, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 869ms/step - loss: 8.8196e-04 - root_mean_squared_error: 0.0417 - mae: 0.0292 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0685 - val_mae: 0.0544 - lr: 0.0010
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 8.7552e-04 - root_mean_squared_error: 0.0418 - mae: 0.0291
# Epoch 10: Learning Rate = 0.0010000000474974513, Loss = 0.0008755201124586165
#
# Epoch 10: val_loss improved from 0.00235 to 0.00223, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 966ms/step - loss: 8.7552e-04 - root_mean_squared_error: 0.0418 - mae: 0.0291 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0667 - val_mae: 0.0522 - lr: 0.0010
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - loss: 8.4983e-04 - root_mean_squared_error: 0.0412 - mae: 0.0286
# Epoch 11: Learning Rate = 0.0009000000427477062, Loss = 0.0008498347597196698
#
# Epoch 11: val_loss did not improve from 0.00223
# 3/3 [==============================] - 0s 92ms/step - loss: 8.4983e-04 - root_mean_squared_error: 0.0412 - mae: 0.0286 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0678 - val_mae: 0.0531 - lr: 9.0000e-04
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - loss: 8.3333e-04 - root_mean_squared_error: 0.0404 - mae: 0.0280
# Epoch 12: Learning Rate = 0.0009000000427477062, Loss = 0.000833326019346714
#
# Epoch 12: val_loss improved from 0.00223 to 0.00218, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 940ms/step - loss: 8.3333e-04 - root_mean_squared_error: 0.0404 - mae: 0.0280 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0661 - val_mae: 0.0514 - lr: 9.0000e-04
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - loss: 8.2879e-04 - root_mean_squared_error: 0.0409 - mae: 0.0280
# Epoch 13: Learning Rate = 0.0009000000427477062, Loss = 0.0008287947275675833
#
# Epoch 13: val_loss improved from 0.00218 to 0.00204, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 949ms/step - loss: 8.2879e-04 - root_mean_squared_error: 0.0409 - mae: 0.0280 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0638 - val_mae: 0.0494 - lr: 9.0000e-04
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - loss: 8.2377e-04 - root_mean_squared_error: 0.0409 - mae: 0.0280
# Epoch 14: Learning Rate = 0.0009000000427477062, Loss = 0.0008237680303864181
#
# Epoch 14: val_loss did not improve from 0.00204
# 3/3 [==============================] - 0s 93ms/step - loss: 8.2377e-04 - root_mean_squared_error: 0.0409 - mae: 0.0280 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0639 - val_mae: 0.0495 - lr: 9.0000e-04
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - loss: 8.1406e-04 - root_mean_squared_error: 0.0406 - mae: 0.0274
# Epoch 15: Learning Rate = 0.0009000000427477062, Loss = 0.000814061495475471
#
# Epoch 15: val_loss improved from 0.00204 to 0.00189, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 907ms/step - loss: 8.1406e-04 - root_mean_squared_error: 0.0406 - mae: 0.0274 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0615 - val_mae: 0.0474 - lr: 9.0000e-04
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - loss: 8.1306e-04 - root_mean_squared_error: 0.0398 - mae: 0.0272
# Epoch 16: Learning Rate = 0.0009000000427477062, Loss = 0.0008130556670948863
#
# Epoch 16: val_loss improved from 0.00189 to 0.00182, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 970ms/step - loss: 8.1306e-04 - root_mean_squared_error: 0.0398 - mae: 0.0272 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0603 - val_mae: 0.0463 - lr: 9.0000e-04
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - loss: 8.1344e-04 - root_mean_squared_error: 0.0405 - mae: 0.0277
# Epoch 17: Learning Rate = 0.0009000000427477062, Loss = 0.0008134432137012482
#
# Epoch 17: val_loss improved from 0.00182 to 0.00181, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 959ms/step - loss: 8.1344e-04 - root_mean_squared_error: 0.0405 - mae: 0.0277 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0602 - val_mae: 0.0462 - lr: 9.0000e-04
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - loss: 8.0387e-04 - root_mean_squared_error: 0.0403 - mae: 0.0273
# Epoch 18: Learning Rate = 0.0009000000427477062, Loss = 0.0008038677624426782
#
# Epoch 18: val_loss improved from 0.00181 to 0.00174, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 889ms/step - loss: 8.0387e-04 - root_mean_squared_error: 0.0403 - mae: 0.0273 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0590 - val_mae: 0.0451 - lr: 9.0000e-04
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - loss: 8.0598e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272
# Epoch 19: Learning Rate = 0.0009000000427477062, Loss = 0.0008059832034632564
#
# Epoch 19: val_loss improved from 0.00174 to 0.00168, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 965ms/step - loss: 8.0598e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0580 - val_mae: 0.0442 - lr: 9.0000e-04
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 8.0387e-04 - root_mean_squared_error: 0.0405 - mae: 0.0274
# Epoch 20: Learning Rate = 0.0009000000427477062, Loss = 0.000803869916126132
#
# Epoch 20: val_loss improved from 0.00168 to 0.00164, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 946ms/step - loss: 8.0387e-04 - root_mean_squared_error: 0.0405 - mae: 0.0274 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0573 - val_mae: 0.0436 - lr: 9.0000e-04
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 8.0075e-04 - root_mean_squared_error: 0.0403 - mae: 0.0271
# Epoch 21: Learning Rate = 0.00072900002123788, Loss = 0.0008007491705939174
#
# Epoch 21: val_loss improved from 0.00164 to 0.00159, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 948ms/step - loss: 8.0075e-04 - root_mean_squared_error: 0.0403 - mae: 0.0271 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0563 - val_mae: 0.0428 - lr: 7.2900e-04
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9842e-04 - root_mean_squared_error: 0.0399 - mae: 0.0270
# Epoch 22: Learning Rate = 0.00072900002123788, Loss = 0.0007984185358509421
#
# Epoch 22: val_loss improved from 0.00159 to 0.00154, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 888ms/step - loss: 7.9842e-04 - root_mean_squared_error: 0.0399 - mae: 0.0270 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0555 - val_mae: 0.0420 - lr: 7.2900e-04
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9883e-04 - root_mean_squared_error: 0.0402 - mae: 0.0271
# Epoch 23: Learning Rate = 0.00072900002123788, Loss = 0.0007988308207131922
#
# Epoch 23: val_loss improved from 0.00154 to 0.00150, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 988ms/step - loss: 7.9883e-04 - root_mean_squared_error: 0.0402 - mae: 0.0271 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0548 - val_mae: 0.0414 - lr: 7.2900e-04
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9850e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272
# Epoch 24: Learning Rate = 0.00072900002123788, Loss = 0.0007984998519532382
#
# Epoch 24: val_loss improved from 0.00150 to 0.00148, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 939ms/step - loss: 7.9850e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0544 - val_mae: 0.0410 - lr: 7.2900e-04
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9907e-04 - root_mean_squared_error: 0.0402 - mae: 0.0271
# Epoch 25: Learning Rate = 0.00072900002123788, Loss = 0.0007990668527781963
#
# Epoch 25: val_loss improved from 0.00148 to 0.00144, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 881ms/step - loss: 7.9907e-04 - root_mean_squared_error: 0.0402 - mae: 0.0271 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0537 - val_mae: 0.0404 - lr: 7.2900e-04
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9720e-04 - root_mean_squared_error: 0.0399 - mae: 0.0269
# Epoch 26: Learning Rate = 0.00072900002123788, Loss = 0.0007971960003487766
#
# Epoch 26: val_loss improved from 0.00144 to 0.00143, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 975ms/step - loss: 7.9720e-04 - root_mean_squared_error: 0.0399 - mae: 0.0269 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0535 - val_mae: 0.0402 - lr: 7.2900e-04
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9729e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272
# Epoch 27: Learning Rate = 0.00072900002123788, Loss = 0.0007972875609993935
#
# Epoch 27: val_loss improved from 0.00143 to 0.00141, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 950ms/step - loss: 7.9729e-04 - root_mean_squared_error: 0.0403 - mae: 0.0272 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0532 - val_mae: 0.0399 - lr: 7.2900e-04
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9878e-04 - root_mean_squared_error: 0.0400 - mae: 0.0271
# Epoch 28: Learning Rate = 0.00072900002123788, Loss = 0.0007987757562659681
#
# Epoch 28: val_loss improved from 0.00141 to 0.00139, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 957ms/step - loss: 7.9878e-04 - root_mean_squared_error: 0.0400 - mae: 0.0271 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0528 - val_mae: 0.0396 - lr: 7.2900e-04
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9662e-04 - root_mean_squared_error: 0.0395 - mae: 0.0269
# Epoch 29: Learning Rate = 0.00072900002123788, Loss = 0.000796619919128716
#
# Epoch 29: val_loss improved from 0.00139 to 0.00137, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 961ms/step - loss: 7.9662e-04 - root_mean_squared_error: 0.0395 - mae: 0.0269 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0524 - val_mae: 0.0392 - lr: 7.2900e-04
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9932e-04 - root_mean_squared_error: 0.0408 - mae: 0.0275
# Epoch 30: Learning Rate = 0.00072900002123788, Loss = 0.0007993237813934684
#
# Epoch 30: val_loss improved from 0.00137 to 0.00134, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 896ms/step - loss: 7.9932e-04 - root_mean_squared_error: 0.0408 - mae: 0.0275 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0517 - val_mae: 0.0386 - lr: 7.2900e-04
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9633e-04 - root_mean_squared_error: 0.0402 - mae: 0.0270
# Epoch 31: Learning Rate = 0.0005314410082064569, Loss = 0.0007963272510096431
#
# Epoch 31: val_loss did not improve from 0.00134
# 3/3 [==============================] - 0s 93ms/step - loss: 7.9633e-04 - root_mean_squared_error: 0.0402 - mae: 0.0270 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0521 - val_mae: 0.0391 - lr: 5.3144e-04
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9515e-04 - root_mean_squared_error: 0.0395 - mae: 0.0268
# Epoch 32: Learning Rate = 0.0005314410082064569, Loss = 0.0007951486622914672
#
# Epoch 32: val_loss did not improve from 0.00134
# 3/3 [==============================] - 0s 93ms/step - loss: 7.9515e-04 - root_mean_squared_error: 0.0395 - mae: 0.0268 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0525 - val_mae: 0.0394 - lr: 5.3144e-04
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9327e-04 - root_mean_squared_error: 0.0391 - mae: 0.0265
# Epoch 33: Learning Rate = 0.0005314410082064569, Loss = 0.0007932694861665368
#
# Epoch 33: val_loss did not improve from 0.00134
# 3/3 [==============================] - 0s 94ms/step - loss: 7.9327e-04 - root_mean_squared_error: 0.0391 - mae: 0.0265 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0521 - val_mae: 0.0390 - lr: 5.3144e-04
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9459e-04 - root_mean_squared_error: 0.0397 - mae: 0.0268
# Epoch 34: Learning Rate = 0.0005314410082064569, Loss = 0.0007945937686599791
#
# Epoch 34: val_loss improved from 0.00134 to 0.00133, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 1s/step - loss: 7.9459e-04 - root_mean_squared_error: 0.0397 - mae: 0.0268 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0515 - val_mae: 0.0385 - lr: 5.3144e-04
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9293e-04 - root_mean_squared_error: 0.0399 - mae: 0.0269
# Epoch 35: Learning Rate = 0.0005314410082064569, Loss = 0.000792931008618325
#
# Epoch 35: val_loss improved from 0.00133 to 0.00131, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 946ms/step - loss: 7.9293e-04 - root_mean_squared_error: 0.0399 - mae: 0.0269 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0512 - val_mae: 0.0382 - lr: 5.3144e-04
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9406e-04 - root_mean_squared_error: 0.0394 - mae: 0.0267
# Epoch 36: Learning Rate = 0.0005314410082064569, Loss = 0.0007940572686493397
#
# Epoch 36: val_loss did not improve from 0.00131
# 3/3 [==============================] - 0s 95ms/step - loss: 7.9406e-04 - root_mean_squared_error: 0.0394 - mae: 0.0267 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0512 - val_mae: 0.0382 - lr: 5.3144e-04
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9383e-04 - root_mean_squared_error: 0.0401 - mae: 0.0270
# Epoch 37: Learning Rate = 0.0005314410082064569, Loss = 0.0007938307826407254
#
# Epoch 37: val_loss did not improve from 0.00131
# 3/3 [==============================] - 0s 93ms/step - loss: 7.9383e-04 - root_mean_squared_error: 0.0401 - mae: 0.0270 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0512 - val_mae: 0.0382 - lr: 5.3144e-04
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9460e-04 - root_mean_squared_error: 0.0396 - mae: 0.0267
# Epoch 38: Learning Rate = 0.0005314410082064569, Loss = 0.0007945971447043121
#
# Epoch 38: val_loss improved from 0.00131 to 0.00130, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 878ms/step - loss: 7.9460e-04 - root_mean_squared_error: 0.0396 - mae: 0.0267 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0510 - val_mae: 0.0381 - lr: 5.3144e-04
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 7.9532e-04 - root_mean_squared_error: 0.0397 - mae: 0.0268
# Epoch 39: Learning Rate = 0.0005314410082064569, Loss = 0.0007953178137540817
#
# Epoch 39: val_loss improved from 0.00130 to 0.00129, saving model to best_model_weekly_multiple_features
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# INFO:tensorflow:Assets written to: best_model_weekly_multiple_features/assets
# 3/3 [==============================] - 2s 973ms/step - loss: 7.9532e-04 - root_mean_squared_error: 0.0397 - mae: 0.0268 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0508 - val_mae: 0.0379 - lr: 5.3144e-04
# /Users/inderkaur/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print(f'\nBest Learning Rate: {best_lr}, Best Validation Loss: {best_val_loss}')
# Out:
# Best Learning Rate: 0.001, Best Validation Loss: 0.001288498635403812

# %%
plt.figure(figsize=(5, 4))
# Plot the performance of each initial learning rate
plt.bar([str(lr) for lr in initial_learning_rates], validation_losses)
plt.xlabel('Initial Learning Rate')
plt.ylabel('Validation Loss')
plt.title('Model Performance vs. Initial Learning Rate')
plt.show()

# %%
[str(lr) for lr in initial_learning_rates], validation_losses
# Out:
# (['0.001'], [0.001288498635403812])

# %%
from tensorflow.keras.models import load_model

final_model = load_model('best_model_weekly_multiple_features.h5')

# %%
final_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Batch_Norm_1 (BatchNormali  (None, 5, 84)             336
#  zation)
#
#  LSTM_1 (LSTM)               (None, 5, 512)            1222656
#
#  LSTM_2 (LSTM)               (None, 512)               2099200
#
#  Dense_1 (Dense)             (None, 256)               131328
#
#  Returns (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3454805 (13.18 MB)
# Trainable params: 3454637 (13.18 MB)
# Non-trainable params: 168 (672.00 Byte)
# _________________________________________________________________

# %%
final_model.evaluate(my_window.test)
# Out:
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 1/1 [==============================] - 0s 261ms/step - loss: 9.7977e-04 - root_mean_squared_error: 0.0443 - mae: 0.0344
# [0.000979768461547792, 0.044266656041145325, 0.034382160753011703]

# %%
def plot_window(tickers,window_dataset,pandas_dataset,window_size,model,
                figsize=(10,7)):
    """This function plots the observed returns inside a tf.data.Dataset and
    compares them with the predicted returns of a model.

    Inputs:
    -------
    window_dataset (tensorflow.data.Dataset object): dataset with both inputs
        and target values.
    pandas_dataset (pandas DataFrame): dataframe that was used to create the
        window_dataset.
    window_size (int): window size used in the transformation from sequential 
        time series into window time series.
    model (model object): trained model with the capability to predict in a
        similar manner than tensorflow.keras.Model object.
    figsize (tuple, default=(12,100)): tuple with the dimensions of the figure
        where the data will be plotted.
    
    Ouputs:
    -------
    None
    """
    # Determine the X-axis of the plot:
    plot_index = pandas_dataset.iloc[window_size:,:].index

    # Assign in the addecuate format the values of the observed taget variable(s):
    y = np.concatenate([targets for inputs,targets in window_dataset],axis=0)
    
    # Use the model to predict the target variable(s):
    
    y_hat = model.predict(window_dataset)
    print("printing y hat of plot_window function")
    print(y_hat)
    # Adjust the shapes:
    y = y.reshape(y_hat.shape)
    print("printing y of plot_window function")
    print(y)

    # Plot the data:
    for n in range(y_hat.shape[1]):
        print(n)
        print(tickers[n])
        plt.figure(figsize=figsize)
        plt.subplot(y_hat.shape[1],1,n+1)
        plt.ylabel('Return')
        plt.plot(plot_index,y_hat[:,n],label='Predicted',color='maroon')
        plt.plot(plot_index,y[:,n],label='Observed',color='midnightblue',alpha=0.5)
        plt.title(tickers[n])
        plt.legend()

# %%
tickers
# Out:
# ['BK', 'CTAS', 'T', 'CSCO', 'MRK']

# %%
############# Training Results
# Create new WindowGenerator with the data not shuffled:
my_window_2 = WindowGenerator(
    input_width=window_size,
    label_width=1,
    shift=1,
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    label_columns=label_cols,
    batch_size=batch_size,
    shuffle=False)

plot_window(tickers,my_window_2.train,train_df,window_size,final_model)
# Out:
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 3/3 [==============================] - 0s 24ms/step
# printing y hat of plot_window function
# [[ 0.00877702  0.01541711  0.00543745  0.02051447  0.00392624]
#  [ 0.00406872  0.01985229 -0.00188796  0.01384225  0.00085981]
#  [ 0.00337597  0.00993852 -0.00717666  0.01353597 -0.0048832 ]
#  ...
#  [-0.0154613  -0.00311687  0.00207897  0.03172502  0.02349197]
#  [-0.01720148  0.00117811  0.0041252   0.0292788   0.01910886]
#  [-0.01305127 -0.00778283  0.00368324  0.02546681  0.02685549]]
# printing y of plot_window function
# [[-0.00521203 -0.02674329 -0.01907128 -0.02554607 -0.00618555]
#  [ 0.04865244  0.03133053 -0.0027409   0.03381478 -0.00822706]
#  [-0.03759217 -0.02614548 -0.02324467 -0.00661541 -0.04523015]
#  ...
#  [ 0.02940032  0.00610763  0.01375489  0.07511049 -0.01814875]
#  [-0.00647389 -0.00195589  0.00115455  0.010137    0.0083177 ]
#  [ 0.05346876  0.07265478  0.074683    0.02305394  0.03061441]]
# 0
# BK
# 1
# CTAS
# 2
# T
# 3
# CSCO
# 4
# MRK

# %%
plot_window(tickers,my_window_2.test,test_df,window_size,final_model)
# Out:
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 1/1 [==============================] - 0s 34ms/step
# printing y hat of plot_window function
# [[-1.88235454e-02  4.30992804e-02  2.10686419e-02  4.09359811e-03
#   -3.08663733e-02]
#  [-2.61637047e-02  3.01417019e-02  1.72432680e-02  5.36771817e-03
#   -3.03966142e-02]
#  [-3.23695689e-02  2.57192608e-02  3.93884163e-03  6.82500703e-03
#   -2.13828273e-02]
#  [-2.82777008e-02  1.74309742e-02 -4.87690885e-03 -1.75163953e-03
#   -1.59673728e-02]
#  [-1.82071142e-02  1.68812070e-02 -3.52785829e-03 -3.26762581e-03
#   -7.96929747e-03]
#  [-6.32291287e-03  1.04195001e-02 -1.34161441e-02  6.54767780e-03
#   -6.78361207e-03]
#  [ 4.60671633e-03 -8.10516905e-03 -1.01590613e-02  1.46631328e-02
#    1.57587463e-04]
#  [ 5.01891971e-03 -4.90644062e-03 -2.77223494e-02  2.00374965e-02
#   -9.28171352e-03]
#  [-5.44049218e-03 -1.40465228e-02 -2.97922473e-02  1.57812573e-02
#   -2.65042833e-03]
#  [-2.08573751e-02 -1.25753572e-02 -3.49974670e-02  7.06266938e-03
#   -6.97955862e-03]
#  [-2.17123590e-02 -1.60782393e-02 -3.83804403e-02 -5.21326112e-03
#    4.04175604e-04]
#  [-2.83352546e-02 -9.98382550e-03 -3.28937396e-02 -8.20370112e-03
#    1.83725841e-02]
#  [-1.43226720e-02 -2.50992160e-02 -2.39461940e-02 -3.92295839e-03
#    1.83516629e-02]
#  [-1.44958198e-02 -3.96996848e-02 -2.26900149e-02  1.06083171e-03
#    2.97435299e-02]
#  [-1.90639496e-03 -5.12275957e-02 -1.45930750e-02 -7.96121196e-04
#    3.99535112e-02]
#  [-5.88809699e-03 -5.19794337e-02 -1.72303729e-02  2.15896172e-03
#    5.17638661e-02]
#  [ 2.29201093e-02 -6.09471016e-02 -9.46177822e-03  1.24062912e-03
#    4.18464653e-02]
#  [ 1.72944218e-02 -6.24477379e-02 -1.10109141e-02  1.36950181e-03
#    4.58116718e-02]
#  [ 1.77451782e-02 -6.14419021e-02 -1.14531731e-02 -4.10394045e-03
#    4.23095226e-02]
#  [ 1.19657330e-02 -5.94982281e-02 -7.76487309e-03 -9.45576117e-04
#    3.90476286e-02]
#  [ 5.88049740e-03 -5.56990765e-02 -1.52938152e-02  1.10510467e-02
#    3.85113321e-02]
#  [ 6.26228750e-03 -5.08783124e-02 -1.64049249e-02  1.60206296e-02
#    4.69042324e-02]
#  [ 1.97858065e-02 -4.69420925e-02 -5.64955268e-03  1.40607310e-02
#    4.58989628e-02]
#  [ 1.97921246e-02 -4.47586663e-02 -1.29214739e-02  1.37831001e-02
#    4.07150276e-02]
#  [ 2.19042152e-02 -4.46052700e-02 -1.56181147e-02 -1.53802917e-04
#    2.92230286e-02]
#  [-6.54868037e-03 -3.47067155e-02 -3.12665403e-02  1.32830755e-03
#    1.79207847e-02]
#  [-2.62593515e-02 -2.30454523e-02 -3.66571359e-02 -1.00972997e-02
#    1.91924274e-02]
#  [-2.59248875e-02 -1.01847155e-02 -3.24825794e-02 -1.71354003e-02
#    2.39796769e-02]
#  [-2.22581662e-02  4.43362957e-03 -2.56153923e-02 -1.77059621e-02
#    1.18985996e-02]
#  [-1.60277374e-02  8.53881706e-03 -1.00249173e-02 -1.10981697e-02
#    1.18902884e-02]
#  [-5.87910414e-03  6.87499112e-03  1.03698475e-02 -4.07037558e-03
#   -1.67908124e-03]
#  [-7.00862706e-03  3.97047913e-03  1.80827584e-02  5.29514579e-03
#   -9.79293138e-03]
#  [-1.31596867e-02 -5.83201880e-03  1.63001921e-02  1.78594626e-02
#   -3.33812437e-03]
#  [-2.53399462e-03 -3.08683747e-03  3.15984748e-02  1.71411149e-02
#   -1.20658032e-03]
#  [-1.98833644e-03 -1.31492643e-02  3.34429070e-02  2.24865712e-02
#   -1.01382211e-02]
#  [ 2.05992162e-02 -2.61282120e-02  2.40293033e-02  1.83254592e-02
#   -2.41355915e-02]
#  [ 3.01495101e-02 -4.03340086e-02  1.60170551e-02  1.52215799e-02
#   -2.41377242e-02]
#  [ 2.98265796e-02 -4.16367464e-02 -5.49462857e-05 -1.02071895e-03
#   -9.15322825e-03]
#  [ 6.68647327e-03 -2.81132963e-02 -2.29485277e-02 -1.42645522e-03
#    7.40717724e-03]
#  [-1.62084438e-02 -6.87714899e-03 -4.53983210e-02  1.11925704e-02
#    1.44405290e-02]
#  [-3.41114774e-02  6.23447215e-03 -5.59806712e-02  2.32245494e-02
#    3.76233719e-02]
#  [-4.88324426e-02  1.58904027e-02 -6.28667474e-02  2.39671059e-02
#    5.48273213e-02]
#  [-5.76802902e-02  1.10195698e-02 -4.83620800e-02  1.97348110e-02
#    5.37513196e-02]
#  [-5.50760590e-02  1.33406126e-03 -1.69557389e-02  1.59057602e-02
#    3.77817936e-02]
#  [-4.00797799e-02 -2.38513434e-03  8.20955541e-03  1.70937143e-02
#    1.95390061e-02]
#  [-1.26626641e-02  3.81207233e-03  3.17530222e-02  2.29003318e-02
#    1.06021948e-02]
#  [ 1.61962919e-02  6.05485355e-03  5.27528450e-02  2.90469434e-02
#    3.76934954e-03]
#  [ 1.81669109e-02  8.84193648e-03  5.86867295e-02  1.99269745e-02
#   -4.87459823e-03]
#  [ 1.83838066e-02  9.97362076e-04  4.61483486e-02  1.94206201e-02
#   -3.87626491e-03]
#  [ 3.38345021e-03 -1.27352504e-02  2.44150758e-02  2.45032553e-02
#   -1.66794173e-02]
#  [-8.69159028e-03 -1.95650849e-02  7.90573470e-03  2.10610069e-02
#   -8.46757367e-03]
#  [ 8.44972581e-03 -1.65057126e-02 -6.53780438e-03  6.93048863e-03
#    1.24985166e-02]
#  [ 4.06628549e-02 -1.49166314e-02 -1.35479840e-02  2.62261201e-02
#    2.67171883e-03]
#  [ 6.39828742e-02 -2.10582744e-02 -5.39533142e-03  6.23327531e-02
#    6.74763694e-03]
#  [ 8.75768736e-02 -2.23617014e-02  2.96500083e-02  8.01794901e-02
#    4.70302999e-03]
#  [ 9.72350910e-02 -6.00655610e-03  5.34405708e-02  5.30669205e-02
#    1.23006720e-02]
#  [ 6.91267326e-02 -6.23032497e-03  5.24144247e-02  3.02922893e-02
#    1.46984705e-03]
#  [ 5.42727262e-02  5.83303208e-03  4.11465727e-02  1.28020933e-02
#   -1.35931484e-02]
#  [ 4.91593108e-02  1.74136702e-02  2.12260056e-02 -3.83234257e-03
#   -2.38244440e-02]
#  [ 3.96699570e-02  1.25226879e-03  1.08068890e-03  1.20290024e-02
#   -3.55018340e-02]
#  [ 2.92030871e-02 -2.79764691e-03 -5.01320735e-02  3.20687965e-02
#   -3.07028182e-02]
#  [ 1.62766650e-02  4.82579088e-03 -5.72797544e-02  4.65177223e-02
#   -1.17559768e-02]
#  [ 6.25272840e-03  2.29523387e-02 -5.90376146e-02  3.15324068e-02
#    1.98969468e-02]
#  [ 6.01954758e-03  2.94945519e-02 -5.09091206e-02  6.16099639e-03
#    2.16882378e-02]
#  [ 8.01771879e-03  2.70962473e-02 -3.35119031e-02 -1.67303495e-02
#    1.41581409e-02]
#  [ 1.39373653e-02  2.65265498e-02 -1.49612157e-02 -2.79610809e-02
#    1.20280720e-02]
#  [ 1.79643314e-02  2.43162047e-02 -1.00924456e-02 -1.62477028e-02
#    1.36570241e-02]
#  [ 4.45261076e-02  2.61551943e-02 -1.32498248e-02 -1.30721731e-02
#    1.93000236e-03]
#  [ 6.23188354e-02  2.14877781e-02 -1.24614174e-02 -1.20318932e-02
#   -1.84060149e-02]
#  [ 5.25439009e-02  2.14863848e-02 -2.45930050e-02  1.03109451e-02
#   -2.18288954e-02]
#  [ 5.51551431e-02  1.68948881e-02 -4.22531255e-02  2.63414476e-02
#   -1.07598789e-02]
#  [ 3.88767719e-02  1.68981906e-02 -6.16811216e-02  3.49067971e-02
#   -3.66353593e-03]
#  [ 2.34347433e-02  1.18495794e-02 -5.37240393e-02  2.82086954e-02
#   -4.35114652e-03]]
# printing y of plot_window function
# [[ 3.99197452e-02 -3.25421407e-03 -5.04091233e-02  1.44666182e-02
#   -1.28234550e-02]
#  [ 4.82768548e-04  2.32859943e-02 -1.58566646e-02  8.91054864e-04
#    1.46297067e-02]
#  [ 6.03295863e-03 -2.98990738e-02  3.11731789e-02 -1.34345787e-02
#    6.33936143e-03]
#  [ 9.28279534e-02 -1.19324615e-02  3.74311209e-03  3.18469964e-02
#    4.99014221e-02]
#  [-9.35031250e-02 -3.34905423e-02  8.31332430e-03 -7.27503095e-03
#   -4.52941246e-02]
#  [-1.25738466e-02 -8.04540608e-03 -1.58021878e-02  8.21673498e-03
#   -4.67036515e-02]
#  [ 3.65703069e-02  7.26902634e-02  4.18852596e-03  7.79735595e-02
#   -2.99897231e-02]
#  [ 4.24313620e-02 -2.26742458e-02  1.91170126e-02 -7.17204437e-02
#   -1.46582536e-03]
#  [-1.14344177e-03  1.28634758e-02 -4.19507995e-02  1.07859103e-02
#   -3.40317450e-02]
#  [ 4.46428061e-02 -1.24101518e-02  6.76395521e-02  3.46252397e-02
#    2.47304384e-02]
#  [ 2.32304633e-02  3.22960019e-02 -2.00058450e-03  3.99918668e-02
#    3.68042290e-02]
#  [-3.16985324e-02 -4.34299968e-02  2.00459477e-03  1.80124696e-02
#    1.67913046e-02]
#  [ 5.10951467e-02  1.44797377e-02  1.90063305e-02  4.41351309e-02
#    1.01919919e-02]
#  [ 1.28363967e-02  3.76320034e-02  4.90853144e-03  5.05972747e-03
#   -1.66024417e-02]
#  [ 1.99460797e-02  3.19175236e-03 -2.21191416e-03 -1.60275400e-02
#   -1.01300469e-02]
#  [-4.64453511e-02 -3.21817510e-02  1.00119913e-03  2.48207226e-02
#    1.88925844e-02]
#  [ 2.77719311e-02  1.63493901e-02  3.06769591e-02 -2.28950679e-02
#   -1.67377025e-03]
#  [ 5.08367270e-02  3.60663678e-03  1.90876108e-02 -9.10167955e-03
#   -1.99923627e-02]
#  [ 4.06132489e-02  2.88632754e-02  3.58731411e-02  3.88901681e-02
#    2.88233738e-02]
#  [-3.44360783e-03 -2.19834223e-02 -3.86148468e-02 -4.13850043e-03
#    2.17473283e-02]
#  [-6.71910774e-03  7.10159214e-03 -5.16416728e-02  8.50016903e-03
#   -1.05169937e-02]
#  [ 1.54611666e-03 -2.18311138e-02 -2.25210544e-02  9.92689561e-03
#   -3.46146338e-02]
#  [-4.20686714e-02  1.86274759e-02  3.43971828e-04  4.63664904e-03
#    4.53094617e-02]
#  [ 4.02922742e-04  2.69771814e-02 -5.50019229e-03 -1.82758309e-02
#    1.72302071e-02]
#  [ 2.41642967e-02  4.63078544e-02 -5.18496195e-03 -4.13686642e-03
#    1.43290497e-03]
#  [-1.14039853e-02  3.28776352e-02  1.37001248e-02  1.21055562e-02
#    8.97748116e-03]
#  [-5.36990836e-02 -3.44073251e-02 -2.42273919e-02 -3.19354562e-03
#   -6.44736877e-03]
#  [ 6.33511618e-02  2.69957110e-02  1.40338605e-02  4.54203114e-02
#    2.46592215e-03]
#  [ 2.04974543e-02  1.46604911e-03 -2.48418329e-03 -3.60625738e-04
#   -1.37235206e-02]
#  [ 4.09517027e-02  7.91030377e-03 -9.24940128e-03  3.60755832e-04
#   -1.12889772e-02]
#  [ 1.66727286e-02  4.91873268e-03  1.25673497e-02  1.46023985e-02
#    3.46521474e-02]
#  [-3.86942667e-03 -3.78738437e-03 -2.41134651e-02  4.01563793e-02
#    5.77434758e-03]
#  [ 2.07175855e-02  4.08237521e-03 -1.05378516e-02  1.00784572e-02
#   -2.39856504e-02]
#  [-5.32800853e-02  3.30342352e-02  1.06500806e-02 -1.74190644e-02
#   -4.33986746e-02]
#  [-5.07274792e-02 -3.18056457e-02 -1.12644397e-02 -3.80378515e-02
#   -8.27232189e-03]
#  [ 7.68302009e-02  4.54773614e-03  6.98270230e-03  5.90444077e-03
#    1.98802631e-02]
#  [-1.02997068e-02 -2.34957505e-02 -5.47441654e-03 -2.88802553e-02
#    1.32769912e-01]
#  [ 5.05203381e-02  4.21393849e-02 -2.00667046e-02  1.29079223e-02
#   -3.81466970e-02]
#  [ 3.40417363e-02  4.64747176e-02 -2.68922113e-02  4.73323883e-03
#   -3.47803906e-02]
#  [ 3.46630067e-02  1.78590175e-02  1.22384951e-02 -9.05936002e-04
#    5.84574938e-02]
#  [ 1.62506085e-02  4.96985205e-03 -1.05303628e-02  1.74101852e-02
#    7.56794438e-02]
#  [-1.73274577e-02  1.42551847e-02 -1.93141904e-02  1.60429124e-02
#   -5.87430447e-02]
#  [ 1.57681089e-02  6.91965641e-03 -3.21552390e-03  4.73678065e-03
#    1.22157717e-02]
#  [-2.83760391e-02  1.07991723e-02 -4.03204979e-03 -4.66213822e-02
#   -2.44951844e-02]
#  [-2.06149388e-02 -2.01279838e-02 -3.27935703e-02  2.12455001e-02
#   -8.26800317e-02]
#  [-2.77144220e-02  1.35714363e-03 -2.55336948e-02  2.15208586e-02
#   -1.96288023e-02]
#  [ 1.26285171e-02  5.07902503e-02 -3.60823609e-02  2.89677419e-02
#    0.00000000e+00]
#  [ 6.23554969e-03 -6.00966439e-02  7.79857561e-02  2.98583824e-02
#    5.05980738e-02]
#  [ 3.61189730e-02  2.82364655e-02  2.43901275e-02  5.06957509e-02
#    2.09391979e-03]
#  [-1.70918283e-04 -4.06939648e-02  2.62308158e-02 -4.09960281e-03
#    3.91815836e-03]
#  [ 7.33207911e-02 -5.86195290e-02  6.86828122e-02 -1.54483672e-02
#    7.15493783e-02]
#  [-6.21018112e-02 -3.23372558e-02 -4.53518704e-03 -7.95858651e-02
#   -4.29768674e-02]
#  [ 1.20068332e-02  1.34860864e-02 -3.18905115e-02 -2.16169525e-02
#    3.36165763e-02]
#  [ 5.04556261e-02 -2.97804642e-02 -6.15686253e-02 -8.98142438e-03
#   -4.78645675e-02]
#  [-1.25300251e-02 -2.21928321e-02  5.01466915e-03 -3.60703655e-02
#   -1.43078286e-02]
#  [-1.35350615e-01  1.30093200e-02 -1.49689438e-02  4.87026311e-02
#    1.43857184e-03]
#  [-5.90781905e-02 -1.14568686e-02 -5.06535359e-03 -3.22762760e-03
#    1.50169805e-02]
#  [ 1.03979502e-02  1.07542500e-02 -2.88503431e-02 -2.32056510e-02
#    9.54437349e-03]
#  [ 3.26539949e-02  4.34388034e-02  1.17955850e-02  3.13076191e-02
#    1.64565369e-02]
#  [ 6.32420788e-03  8.16253945e-02  3.06564905e-02 -1.53571684e-02
#    2.71942932e-02]
#  [-5.71319908e-02  1.41292317e-02  1.29869068e-02  1.32389665e-02
#    2.80753765e-02]
#  [-2.90849637e-02 -2.61171870e-02  7.48601183e-02 -4.70355451e-02
#    3.76093350e-02]
#  [-3.86936441e-02 -1.15548866e-02  5.63245546e-03 -3.34719382e-02
#   -6.46414747e-03]
#  [-3.98181863e-02 -7.79318344e-03  2.56933505e-03  1.62394997e-02
#   -7.31964223e-03]
#  [-3.00144535e-02 -4.51263376e-02 -1.99897327e-02 -4.00462635e-02
#    2.58660614e-02]
#  [ 1.19437911e-02 -4.40146402e-02  2.24895589e-02 -1.80504695e-02
#   -1.14058690e-04]
#  [ 6.94272632e-04  1.19709074e-02  3.73402648e-02  8.16882937e-04
#    5.34001924e-02]
#  [ 3.33024301e-02 -1.97230857e-02  2.26824600e-02 -1.15306042e-01
#    1.63562186e-02]
#  [ 2.84243189e-02  7.32959285e-02  9.64315888e-03  4.56747971e-02
#   -4.25237939e-02]
#  [-9.74971876e-02 -9.95672569e-02 -5.63514642e-02 -4.61063422e-02
#   -5.38734309e-02]
#  [ 3.83409373e-02  6.16459250e-02  5.16192801e-02  1.22571550e-02
#    1.19796082e-01]
#  [-3.13517563e-02  2.26364308e-03  7.46769318e-03 -2.98675196e-03
#   -1.16514589e-03]
#  [ 2.54137162e-02 -4.83235391e-03 -6.29239716e-03 -1.50289591e-02
#   -2.07848549e-02]]
# 0
# BK
# 1
# CTAS
# 2
# T
# 3
# CSCO
# 4
# MRK

# %%
def optimize_portfolio(returns,guess_weights=None,rfr=0):
    """This function optimizes the weight allocation for the assets in a
    portfolio, represented by the returns.

    Inputs:
    -------
    returns (pandas DataFrame|Series): contains the returns information.
    guess_weights (list of numerical values, default=None): guess values for
        the weights of the different assets in the portfolio.
    short (boolena, default=True): define ifshort possitions are allowed or 
        not.
    rfr (numerical value, default=0): risk free rate, could be a series of
        the same length as returns.

    Outputs:
    --------
    opt_weights (array-like object): array with the optimal weights for the
        portfolio.
    """
    # Define important variables:
#     print("KIIIIIIII")
    num_assets = returns.shape[1]
    if isinstance(guess_weights,type(None)):
        guess_weights = [1/num_assets for i in range(num_assets)]

    # Define bound if short possitions are allowed or not:
    
    bounds = [(0,1) for i in range(num_assets)]
    

    # Define constraints, if there can or not be leverage
    weights_sum_to_1 = {'type':'eq',
                        'fun':lambda weights: np.sum(np.absolute(weights))-1}
#     print("sharpe ratio:::::::::::")
#     print(sharpe_ratio)
#     print("returns:::::::::::::::")
#     print(returns)
    # Minimize the function:
    opt_weights = spo.minimize(
        sharpe_ratio,
        guess_weights,
        args = (rfr, True, returns),
        method = 'SLSQP',
        options = {'disp':False},
        constraints = (weights_sum_to_1),
        bounds = bounds
    )

    return opt_weights

# %%
def daily_rate(x, periods_year=252):
    """This function transforms a rate into a daily rate

    Inputs:
    -------
    x (numerical value): rate that you want to transform into a daily rate.
    periods_year (numerical value, default=252): amount of periods per year
        of the periodicity of rate x.
    
    Ouputs:
    -------
    df (numerical value): daily rate
    """
    dr = np.power(1+x,1/periods_year)-1
    return dr

# %%
def sharpe_ratio(weights=None, rfr=0, negative=False, returns=0):
    """Compute the Sharpe Ratio of a portfolio.

    Inputs:
    -------
    weights (list of numerical values, default=None): list with the weights
        of the assets in the portfolio.
    rfr (numerical value|array-like, default=0): risk-free rate.
    returns (pandas DataFrame|Series, default=0): returns of the assets in
        the portfolio.

    Outputs:
    --------
    sharpe_ratio (numerical value): Sharpe ratio of the portfolio.
    """
    # Define important variables:
    num_assets = returns.shape[1]
    if isinstance(weights,type(None)):
        weights = [1/num_assets for i in range(num_assets)]

    # Get portfolio returns:
    portfolio_returns = (returns*weights).sum(axis=1)
    portfolio_std = portfolio_returns.std()

    # Compute Sharpe Ratio formula:
    sharpe_ratio = (portfolio_returns-rfr).mean()/portfolio_std

    # If used in a minization process:
    if negative:
        sharpe_ratio *= -1

    return sharpe_ratio

# %%
columns = ['FR_'+ticker for ticker in tickers]
y_train = final_model.predict(my_window_2.train)
y_val = final_model.predict(my_window_2.val)
y_test = final_model.predict(my_window_2.test)
y_hat_total = np.concatenate([y_train,y_val,y_test],axis=0)
ret_hat_df = pd.DataFrame(data=y_hat_total,index=model_data.index[5:],columns=columns)
rfr = data_quandl['3m_rate'].agg(daily_rate)
ret_hat_df = ret_hat_df.merge(rfr.rename('rfr'),left_index=True,right_index=True,
                             how='left')

opt_weights = np.array([optimize_portfolio(
    returns = window[ret_hat_df.columns[:-1]],
    rfr = window[ret_hat_df.columns[-1]]).x for window in ret_hat_df.rolling(40)])
opt_weights.shape

# Display the shape of opt_weights
print(f"Shape of optimized weights: {opt_weights.shape}")
# Out:
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 3/3 [==============================] - 0s 23ms/step
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 1/1 [==============================] - 0s 47ms/step
# ************************************************
# <_MapDataset element_spec=(TensorSpec(shape=(None, 5, 84), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1, 5), dtype=tf.float32, name=None))>
# 1/1 [==============================] - 0s 40ms/step
# Shape of optimized weights: (716, 5)

# %%
model_data.shape
# Out:
# (721, 84)

# %%
opt_weights
# Out:
# array([[2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        [5.45213026e-16, 6.00636468e-01, 8.93800887e-16, 3.99363532e-01,
#         5.15387875e-08],
#        [0.00000000e+00, 3.45215331e-01, 0.00000000e+00, 6.54784669e-01,
#         0.00000000e+00],
#        ...,
#        [1.15185093e-01, 2.53659561e-01, 1.18611718e-16, 5.58710123e-01,
#         7.24452216e-02],
#        [1.34655464e-01, 2.20711806e-01, 0.00000000e+00, 5.32093242e-01,
#         1.12539488e-01],
#        [1.56606073e-01, 2.01757530e-01, 0.00000000e+00, 4.93599845e-01,
#         1.48036553e-01]])
